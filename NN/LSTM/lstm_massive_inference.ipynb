# %%
import os
import re
import torch
import numpy as np
from train import NOELSTM

# Load data
theta = np.load("theta.npy")
omega = np.load("omega.npy")
u = np.load("u.npy")

# Normalize
theta_mean, theta_std = theta.mean(), theta.std()
omega_mean, omega_std = omega.mean(), omega.std()
u_mean, u_std = u.mean(), u.std()

theta_norm = (theta - theta_mean) / theta_std
omega_norm = (omega - omega_mean) / omega_std
u_norm = (u - u_mean) / u_std

def create_sequences(theta, omega, u, seq_len):
    X, Y = [], []
    for i in range(len(theta) - seq_len):
        x_seq = np.stack([theta[i:i+seq_len], omega[i:i+seq_len], u[i:i+seq_len]], axis=1)
        y_target = [theta[i+seq_len], omega[i+seq_len]]
        X.append(x_seq)
        Y.append(y_target)
    return np.array(X), np.array(Y)

def unnormalize(preds):
    preds_unnorm = np.empty_like(preds)
    preds_unnorm[:, 0] = preds[:, 0] * theta_std + theta_mean
    preds_unnorm[:, 1] = preds[:, 1] * omega_std + omega_mean
    return preds_unnorm

def print_metrics(pred, true):
    rms = np.sqrt(np.mean((pred - true)**2))
    deg = rms / (2 * np.pi) * 360
    nrms = rms / np.std(true) * 100
    return rms, deg, nrms

model_stats = []

model_dir = "new_models"
model_files = [f for f in os.listdir(model_dir) if f.startswith("model_hs") and f.endswith(".pt")]

for model_file in model_files:
    path = os.path.join(model_dir, model_file)

    # Extract hyperparameters
    filename_no_ext = os.path.splitext(model_file)[0]  # "best_model_..."
    match = re.search(
        r"hs(\d+)_lr([\d.]+)_nl(\d+)_bs(\d+)_sl(\d+)_ep(\d+)_bi(\d+)_do([\d.]+)", filename_no_ext
    )
    if not match:
        print(f"Skipping {model_file} (couldn't parse hyperparameters).")
        continue

    hs, lr, nl, bs, sl, ep, bi, do = match.groups()
    hs, nl, sl = int(hs), int(nl), int(sl)
    bi = bool(int(bi))
    do = float(do)

    # Prepare data
    X, Y = create_sequences(theta_norm, omega_norm, u_norm, sl)
    X_tensor = torch.tensor(X).double()
    Y_tensor = torch.tensor(Y).double()

    # Train/val split
    n = len(X_tensor)
    train_end = int(0.8 * n)
    val_end = int(0.9 * n)
    
    X_train, Y_train = X_tensor[:train_end], Y_tensor[:train_end]
    X_val, Y_val = X_tensor[train_end:val_end], Y_tensor[train_end:val_end]
    X_test, Y_test = X_tensor[val_end:], Y_tensor[val_end:]

    # Load model
    model = NOELSTM(input_size=3, hidden_size=hs, num_layers=nl, 
                    output_size=2, bidirectional=bi, dropout=do)
    try:
        model.load_state_dict(torch.load(path, map_location='cpu'))
    except Exception as e:
        print(f"Error loading {model_file}: {e}")
        continue

    model.eval()
    with torch.no_grad():
        train_pred = model(X_train).numpy()
        val_pred = model(X_val).numpy()

    # Unnormalize
    train_pred = unnormalize(train_pred)
    val_pred = unnormalize(val_pred)
    Y_train_true = unnormalize(Y_train.numpy())
    Y_val_true = unnormalize(Y_val.numpy())

    # Evaluate
    train_rms, train_deg, train_nrms = print_metrics(train_pred[:, 0], Y_train_true[:, 0])
    val_rms, val_deg, val_nrms = print_metrics(val_pred[:, 0], Y_val_true[:, 0])

    model_stats.append({
        "model_file": model_file,
        "train_rms": train_rms,
        "train_deg": train_deg,
        "train_nrms": train_nrms,
        "val_rms": val_rms,
        "val_deg": val_deg,
        "val_nrms": val_nrms
    })

    # Per-model print
    print(f"\n=== {model_file} ===")
    print(f"Train RMS: {train_rms:.5f} rad | {train_deg:.2f}° | NRMS: {train_nrms:.2f}%")
    print(f"Val   RMS: {val_rms:.5f} rad | {val_deg:.2f}° | NRMS: {val_nrms:.2f}%")

# Top 5 by Validation RMS (Theta)
top_5 = sorted(model_stats, key=lambda x: x['val_rms'])[:5]

print("\n=== Top 5 Models by Validation RMS (Theta) ===")
for i, stat in enumerate(top_5, 1):
    print(f"\n#{i}: {stat['model_file']}")
    print(f"  Train RMS: {stat['train_rms']:.5f} rad | {stat['train_deg']:.2f}° | NRMS: {stat['train_nrms']:.2f}%")
    print(f"  Val   RMS: {stat['val_rms']:.5f} rad | {stat['val_deg']:.2f}° | NRMS: {stat['val_nrms']:.2f}%")
# Out:
# === model_hs16_lr0.01_nl1_bs128_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00229 rad | 0.13° | NRMS: 0.49%
# Val   RMS: 0.00316 rad | 0.18° | NRMS: 0.61%
#
# === model_hs16_lr0.01_nl1_bs128_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00160 rad | 0.09° | NRMS: 0.34%
# Val   RMS: 0.00200 rad | 0.11° | NRMS: 0.39%
#
# === model_hs16_lr0.01_nl1_bs128_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00167 rad | 0.10° | NRMS: 0.36%
# Val   RMS: 0.00226 rad | 0.13° | NRMS: 0.44%
#
# === model_hs16_lr0.01_nl1_bs128_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00206 rad | 0.12° | NRMS: 0.44%
# Val   RMS: 0.00291 rad | 0.17° | NRMS: 0.56%
#
# === model_hs16_lr0.01_nl1_bs128_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00160 rad | 0.09° | NRMS: 0.34%
# Val   RMS: 0.00241 rad | 0.14° | NRMS: 0.47%
#
# === model_hs16_lr0.01_nl1_bs128_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00176 rad | 0.10° | NRMS: 0.37%
# Val   RMS: 0.00220 rad | 0.13° | NRMS: 0.43%
#
# === model_hs16_lr0.01_nl1_bs128_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00174 rad | 0.10° | NRMS: 0.37%
# Val   RMS: 0.00200 rad | 0.11° | NRMS: 0.39%
#
# === model_hs16_lr0.01_nl1_bs128_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00183 rad | 0.10° | NRMS: 0.39%
# Val   RMS: 0.00206 rad | 0.12° | NRMS: 0.40%
#
# === model_hs16_lr0.01_nl1_bs128_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00164 rad | 0.09° | NRMS: 0.35%
# Val   RMS: 0.00215 rad | 0.12° | NRMS: 0.42%
#
# === model_hs16_lr0.01_nl1_bs128_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00192 rad | 0.11° | NRMS: 0.41%
# Val   RMS: 0.00236 rad | 0.14° | NRMS: 0.46%
#
# === model_hs16_lr0.01_nl1_bs128_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00208 rad | 0.12° | NRMS: 0.44%
# Val   RMS: 0.00255 rad | 0.15° | NRMS: 0.49%
#
# === model_hs16_lr0.01_nl1_bs128_sl15_ep200_bi1_do0.pt ===
# Train RMS: 0.00208 rad | 0.12° | NRMS: 0.44%
# Val   RMS: 0.00253 rad | 0.14° | NRMS: 0.49%
#
# === model_hs16_lr0.01_nl1_bs128_sl20_ep200_bi0_do0.pt ===
# Train RMS: 0.00341 rad | 0.20° | NRMS: 0.73%
# Val   RMS: 0.00363 rad | 0.21° | NRMS: 0.70%
#
# === model_hs16_lr0.01_nl1_bs128_sl30_ep200_bi0_do0.pt ===
# Train RMS: 0.00231 rad | 0.13° | NRMS: 0.49%
# Val   RMS: 0.00281 rad | 0.16° | NRMS: 0.54%
#
# === model_hs16_lr0.01_nl1_bs128_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00202 rad | 0.12° | NRMS: 0.43%
# Val   RMS: 0.00238 rad | 0.14° | NRMS: 0.46%
#
# === model_hs16_lr0.01_nl1_bs128_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00277 rad | 0.16° | NRMS: 0.59%
# Val   RMS: 0.00350 rad | 0.20° | NRMS: 0.68%
#
# === model_hs16_lr0.01_nl1_bs128_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00229 rad | 0.13° | NRMS: 0.49%
# Val   RMS: 0.00279 rad | 0.16° | NRMS: 0.54%
#
# === model_hs16_lr0.01_nl1_bs128_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00202 rad | 0.12° | NRMS: 0.43%
# Val   RMS: 0.00260 rad | 0.15° | NRMS: 0.50%
#
# === model_hs16_lr0.01_nl1_bs128_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00142 rad | 0.08° | NRMS: 0.30%
# Val   RMS: 0.00178 rad | 0.10° | NRMS: 0.35%
#
# === model_hs16_lr0.01_nl1_bs128_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00183 rad | 0.10° | NRMS: 0.39%
# Val   RMS: 0.00247 rad | 0.14° | NRMS: 0.48%
#
# === model_hs16_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00145 rad | 0.08° | NRMS: 0.31%
# Val   RMS: 0.00195 rad | 0.11° | NRMS: 0.38%
#
# === model_hs16_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00149 rad | 0.09° | NRMS: 0.32%
# Val   RMS: 0.00197 rad | 0.11° | NRMS: 0.38%
#
# === model_hs16_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00188 rad | 0.11° | NRMS: 0.40%
# Val   RMS: 0.00215 rad | 0.12° | NRMS: 0.42%
#
# === model_hs16_lr0.01_nl1_bs64_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00303 rad | 0.17° | NRMS: 0.65%
# Val   RMS: 0.00324 rad | 0.19° | NRMS: 0.63%
#
# === model_hs16_lr0.01_nl1_bs64_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00200 rad | 0.11° | NRMS: 0.43%
# Val   RMS: 0.00262 rad | 0.15° | NRMS: 0.51%
#
# === model_hs16_lr0.01_nl1_bs64_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00348 rad | 0.20° | NRMS: 0.74%
# Val   RMS: 0.00395 rad | 0.23° | NRMS: 0.76%
#
# === model_hs16_lr0.01_nl1_bs64_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00244 rad | 0.14° | NRMS: 0.52%
# Val   RMS: 0.00285 rad | 0.16° | NRMS: 0.55%
#
# === model_hs16_lr0.01_nl1_bs64_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00359 rad | 0.21° | NRMS: 0.76%
# Val   RMS: 0.00415 rad | 0.24° | NRMS: 0.80%
#
# === model_hs16_lr0.01_nl1_bs64_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00198 rad | 0.11° | NRMS: 0.42%
# Val   RMS: 0.00229 rad | 0.13° | NRMS: 0.44%
#
# === model_hs16_lr0.01_nl1_bs64_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00228 rad | 0.13° | NRMS: 0.48%
# Val   RMS: 0.00255 rad | 0.15° | NRMS: 0.49%
#
# === model_hs16_lr0.01_nl1_bs64_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00225 rad | 0.13° | NRMS: 0.48%
# Val   RMS: 0.00257 rad | 0.15° | NRMS: 0.50%
#
# === model_hs16_lr0.01_nl1_bs64_sl15_ep200_bi1_do0.pt ===
# Train RMS: 0.00182 rad | 0.10° | NRMS: 0.39%
# Val   RMS: 0.00224 rad | 0.13° | NRMS: 0.43%
#
# === model_hs16_lr0.01_nl1_bs64_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00157 rad | 0.09° | NRMS: 0.33%
# Val   RMS: 0.00229 rad | 0.13° | NRMS: 0.44%
#
# === model_hs16_lr0.01_nl1_bs64_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00144 rad | 0.08° | NRMS: 0.31%
# Val   RMS: 0.00199 rad | 0.11° | NRMS: 0.38%
#
# === model_hs16_lr0.01_nl1_bs64_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00144 rad | 0.08° | NRMS: 0.31%
# Val   RMS: 0.00181 rad | 0.10° | NRMS: 0.35%
#
# === model_hs16_lr0.01_nl1_bs64_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00304 rad | 0.17° | NRMS: 0.65%
# Val   RMS: 0.00411 rad | 0.24° | NRMS: 0.79%
#
# === model_hs16_lr0.01_nl1_bs64_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00197 rad | 0.11° | NRMS: 0.42%
# Val   RMS: 0.00250 rad | 0.14° | NRMS: 0.48%
#
# === model_hs16_lr0.01_nl1_bs64_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00286 rad | 0.16° | NRMS: 0.61%
# Val   RMS: 0.00324 rad | 0.19° | NRMS: 0.63%
#
# === model_hs16_lr0.01_nl2_bs128_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.16476 rad | 9.44° | NRMS: 35.09%
# Val   RMS: 0.17133 rad | 9.82° | NRMS: 33.14%
#
# === model_hs16_lr0.01_nl2_bs128_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.23089 rad | 13.23° | NRMS: 49.18%
# Val   RMS: 0.25553 rad | 14.64° | NRMS: 49.42%
#
# === model_hs16_lr0.01_nl2_bs128_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00252 rad | 0.14° | NRMS: 0.54%
# Val   RMS: 0.00332 rad | 0.19° | NRMS: 0.64%
#
# === model_hs16_lr0.01_nl2_bs128_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.03716 rad | 2.13° | NRMS: 7.91%
# Val   RMS: 0.04309 rad | 2.47° | NRMS: 8.33%
#
# === model_hs16_lr0.01_nl2_bs128_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.21212 rad | 12.15° | NRMS: 45.18%
# Val   RMS: 0.23292 rad | 13.35° | NRMS: 45.05%
#
# === model_hs16_lr0.01_nl2_bs128_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00293 rad | 0.17° | NRMS: 0.62%
# Val   RMS: 0.00351 rad | 0.20° | NRMS: 0.68%
#
# === model_hs16_lr0.01_nl2_bs128_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.10541 rad | 6.04° | NRMS: 22.45%
# Val   RMS: 0.11603 rad | 6.65° | NRMS: 22.44%
#
# === model_hs16_lr0.01_nl2_bs128_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.48053 rad | 27.53° | NRMS: 102.34%
# Val   RMS: 0.50835 rad | 29.13° | NRMS: 98.31%
#
# === model_hs16_lr0.01_nl2_bs128_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00433 rad | 0.25° | NRMS: 0.92%
# Val   RMS: 0.00471 rad | 0.27° | NRMS: 0.91%
#
# === model_hs16_lr0.01_nl2_bs128_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.01434 rad | 0.82° | NRMS: 3.05%
# Val   RMS: 0.01730 rad | 0.99° | NRMS: 3.35%
#
# === model_hs16_lr0.01_nl2_bs128_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.21020 rad | 12.04° | NRMS: 44.77%
# Val   RMS: 0.22743 rad | 13.03° | NRMS: 43.98%
#
# === model_hs16_lr0.01_nl2_bs128_sl15_ep200_bi1_do0.pt ===
# Train RMS: 0.00219 rad | 0.13° | NRMS: 0.47%
# Val   RMS: 0.00269 rad | 0.15° | NRMS: 0.52%
#
# === model_hs16_lr0.01_nl2_bs128_sl20_ep200_bi0_do0.pt ===
# Train RMS: 0.00153 rad | 0.09° | NRMS: 0.33%
# Val   RMS: 0.00196 rad | 0.11° | NRMS: 0.38%
#
# === model_hs16_lr0.01_nl2_bs128_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.26404 rad | 15.13° | NRMS: 56.24%
# Val   RMS: 0.26873 rad | 15.40° | NRMS: 51.98%
#
# === model_hs16_lr0.01_nl2_bs128_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.80147 rad | 45.92° | NRMS: 170.71%
# Val   RMS: 0.80645 rad | 46.21° | NRMS: 155.98%
#
# === model_hs16_lr0.01_nl2_bs128_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00458 rad | 0.26° | NRMS: 0.98%
# Val   RMS: 0.00558 rad | 0.32° | NRMS: 1.08%
#
# === model_hs16_lr0.01_nl2_bs128_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.04757 rad | 2.73° | NRMS: 10.13%
# Val   RMS: 0.05557 rad | 3.18° | NRMS: 10.75%
#
# === model_hs16_lr0.01_nl2_bs128_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.25297 rad | 14.49° | NRMS: 53.88%
# Val   RMS: 0.26253 rad | 15.04° | NRMS: 50.78%
#
# === model_hs16_lr0.01_nl2_bs128_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00412 rad | 0.24° | NRMS: 0.88%
# Val   RMS: 0.00468 rad | 0.27° | NRMS: 0.91%
#
# === model_hs16_lr0.01_nl2_bs64_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.10774 rad | 6.17° | NRMS: 22.95%
# Val   RMS: 0.11670 rad | 6.69° | NRMS: 22.57%
#
# === model_hs16_lr0.01_nl2_bs64_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.31169 rad | 17.86° | NRMS: 66.38%
# Val   RMS: 0.33183 rad | 19.01° | NRMS: 64.18%
#
# === model_hs16_lr0.01_nl2_bs64_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00430 rad | 0.25° | NRMS: 0.92%
# Val   RMS: 0.00464 rad | 0.27° | NRMS: 0.90%
#
# === model_hs16_lr0.01_nl2_bs64_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.07148 rad | 4.10° | NRMS: 15.22%
# Val   RMS: 0.07718 rad | 4.42° | NRMS: 14.93%
#
# === model_hs16_lr0.01_nl2_bs64_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.23519 rad | 13.48° | NRMS: 50.09%
# Val   RMS: 0.24637 rad | 14.12° | NRMS: 47.65%
#
# === model_hs16_lr0.01_nl2_bs64_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00414 rad | 0.24° | NRMS: 0.88%
# Val   RMS: 0.00557 rad | 0.32° | NRMS: 1.08%
#
# === model_hs16_lr0.01_nl2_bs64_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.12347 rad | 7.07° | NRMS: 26.30%
# Val   RMS: 0.13379 rad | 7.67° | NRMS: 25.87%
#
# === model_hs16_lr0.01_nl2_bs64_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.24424 rad | 13.99° | NRMS: 52.02%
# Val   RMS: 0.26608 rad | 15.25° | NRMS: 51.46%
#
# === model_hs16_lr0.01_nl2_bs64_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00248 rad | 0.14° | NRMS: 0.53%
# Val   RMS: 0.00311 rad | 0.18° | NRMS: 0.60%
#
# === model_hs16_lr0.01_nl2_bs64_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.01662 rad | 0.95° | NRMS: 3.54%
# Val   RMS: 0.02060 rad | 1.18° | NRMS: 3.98%
#
# === model_hs16_lr0.01_nl2_bs64_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.20336 rad | 11.65° | NRMS: 43.31%
# Val   RMS: 0.22164 rad | 12.70° | NRMS: 42.86%
#
# === model_hs16_lr0.01_nl2_bs64_sl15_ep200_bi1_do0.pt ===
# Train RMS: 0.00470 rad | 0.27° | NRMS: 1.00%
# Val   RMS: 0.00534 rad | 0.31° | NRMS: 1.03%
#
# === model_hs16_lr0.01_nl2_bs64_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.19406 rad | 11.12° | NRMS: 41.34%
# Val   RMS: 0.19983 rad | 11.45° | NRMS: 38.65%
#
# === model_hs16_lr0.01_nl2_bs64_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.32231 rad | 18.47° | NRMS: 68.65%
# Val   RMS: 0.34700 rad | 19.88° | NRMS: 67.12%
#
# === model_hs16_lr0.01_nl2_bs64_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00512 rad | 0.29° | NRMS: 1.09%
# Val   RMS: 0.00566 rad | 0.32° | NRMS: 1.09%
#
# === model_hs16_lr0.01_nl2_bs64_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.07130 rad | 4.09° | NRMS: 15.19%
# Val   RMS: 0.08004 rad | 4.59° | NRMS: 15.48%
#
# === model_hs16_lr0.01_nl2_bs64_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.32856 rad | 18.83° | NRMS: 69.98%
# Val   RMS: 0.34174 rad | 19.58° | NRMS: 66.10%
#
# === model_hs16_lr0.01_nl2_bs64_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00230 rad | 0.13° | NRMS: 0.49%
# Val   RMS: 0.00310 rad | 0.18° | NRMS: 0.60%
#
# === model_hs32_lr0.01_nl1_bs128_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00157 rad | 0.09° | NRMS: 0.33%
# Val   RMS: 0.00192 rad | 0.11° | NRMS: 0.37%
#
# === model_hs32_lr0.01_nl1_bs128_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00122 rad | 0.07° | NRMS: 0.26%
# Val   RMS: 0.00160 rad | 0.09° | NRMS: 0.31%
#
# === model_hs32_lr0.01_nl1_bs128_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00183 rad | 0.10° | NRMS: 0.39%
# Val   RMS: 0.00206 rad | 0.12° | NRMS: 0.40%
#
# === model_hs32_lr0.01_nl1_bs128_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00171 rad | 0.10° | NRMS: 0.36%
# Val   RMS: 0.00211 rad | 0.12° | NRMS: 0.41%
#
# === model_hs32_lr0.01_nl1_bs128_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00254 rad | 0.15° | NRMS: 0.54%
# Val   RMS: 0.00321 rad | 0.18° | NRMS: 0.62%
#
# === model_hs32_lr0.01_nl1_bs128_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00168 rad | 0.10° | NRMS: 0.36%
# Val   RMS: 0.00196 rad | 0.11° | NRMS: 0.38%
#
# === model_hs32_lr0.01_nl1_bs128_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00202 rad | 0.12° | NRMS: 0.43%
# Val   RMS: 0.00231 rad | 0.13° | NRMS: 0.45%
#
# === model_hs32_lr0.01_nl1_bs128_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00192 rad | 0.11° | NRMS: 0.41%
# Val   RMS: 0.00219 rad | 0.13° | NRMS: 0.42%
#
# === model_hs32_lr0.01_nl1_bs128_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00241 rad | 0.14° | NRMS: 0.51%
# Val   RMS: 0.00282 rad | 0.16° | NRMS: 0.55%
#
# === model_hs32_lr0.01_nl1_bs128_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00259 rad | 0.15° | NRMS: 0.55%
# Val   RMS: 0.00311 rad | 0.18° | NRMS: 0.60%
#
# === model_hs32_lr0.01_nl1_bs128_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00167 rad | 0.10° | NRMS: 0.36%
# Val   RMS: 0.00209 rad | 0.12° | NRMS: 0.40%
#
# === model_hs32_lr0.01_nl1_bs128_sl15_ep200_bi1_do0.pt ===
# Train RMS: 0.00166 rad | 0.10° | NRMS: 0.35%
# Val   RMS: 0.00248 rad | 0.14° | NRMS: 0.48%
#
# === model_hs32_lr0.01_nl1_bs128_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00143 rad | 0.08° | NRMS: 0.30%
# Val   RMS: 0.00176 rad | 0.10° | NRMS: 0.34%
#
# === model_hs32_lr0.01_nl1_bs128_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00176 rad | 0.10° | NRMS: 0.37%
# Val   RMS: 0.00209 rad | 0.12° | NRMS: 0.40%
#
# === model_hs32_lr0.01_nl1_bs128_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00142 rad | 0.08° | NRMS: 0.30%
# Val   RMS: 0.00175 rad | 0.10° | NRMS: 0.34%
#
# === model_hs32_lr0.01_nl1_bs128_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00202 rad | 0.12° | NRMS: 0.43%
# Val   RMS: 0.00224 rad | 0.13° | NRMS: 0.43%
#
# === model_hs32_lr0.01_nl1_bs128_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00333 rad | 0.19° | NRMS: 0.71%
# Val   RMS: 0.00365 rad | 0.21° | NRMS: 0.71%
#
# === model_hs32_lr0.01_nl1_bs128_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00212 rad | 0.12° | NRMS: 0.45%
# Val   RMS: 0.00257 rad | 0.15° | NRMS: 0.50%
#
# === model_hs32_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00161 rad | 0.09° | NRMS: 0.34%
# Val   RMS: 0.00191 rad | 0.11° | NRMS: 0.37%
#
# === model_hs32_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00143 rad | 0.08° | NRMS: 0.30%
# Val   RMS: 0.00190 rad | 0.11° | NRMS: 0.37%
#
# === model_hs32_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00123 rad | 0.07° | NRMS: 0.26%
# Val   RMS: 0.00146 rad | 0.08° | NRMS: 0.28%
#
# === model_hs32_lr0.01_nl1_bs64_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00161 rad | 0.09° | NRMS: 0.34%
# Val   RMS: 0.00199 rad | 0.11° | NRMS: 0.39%
#
# === model_hs32_lr0.01_nl1_bs64_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00188 rad | 0.11° | NRMS: 0.40%
# Val   RMS: 0.00221 rad | 0.13° | NRMS: 0.43%
#
# === model_hs32_lr0.01_nl1_bs64_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00223 rad | 0.13° | NRMS: 0.47%
# Val   RMS: 0.00281 rad | 0.16° | NRMS: 0.54%
#
# === model_hs32_lr0.01_nl1_bs64_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00156 rad | 0.09° | NRMS: 0.33%
# Val   RMS: 0.00204 rad | 0.12° | NRMS: 0.39%
#
# === model_hs32_lr0.01_nl1_bs64_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00420 rad | 0.24° | NRMS: 0.89%
# Val   RMS: 0.00439 rad | 0.25° | NRMS: 0.85%
#
# === model_hs32_lr0.01_nl1_bs64_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00131 rad | 0.08° | NRMS: 0.28%
# Val   RMS: 0.00175 rad | 0.10° | NRMS: 0.34%
#
# === model_hs32_lr0.01_nl1_bs64_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00137 rad | 0.08° | NRMS: 0.29%
# Val   RMS: 0.00196 rad | 0.11° | NRMS: 0.38%
#
# === model_hs32_lr0.01_nl1_bs64_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00279 rad | 0.16° | NRMS: 0.59%
# Val   RMS: 0.00333 rad | 0.19° | NRMS: 0.64%
#
# === model_hs32_lr0.01_nl1_bs64_sl15_ep200_bi1_do0.pt ===
# Train RMS: 0.00235 rad | 0.13° | NRMS: 0.50%
# Val   RMS: 0.00266 rad | 0.15° | NRMS: 0.51%
#
# === model_hs32_lr0.01_nl1_bs64_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00213 rad | 0.12° | NRMS: 0.45%
# Val   RMS: 0.00251 rad | 0.14° | NRMS: 0.49%
#
# === model_hs32_lr0.01_nl1_bs64_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00122 rad | 0.07° | NRMS: 0.26%
# Val   RMS: 0.00152 rad | 0.09° | NRMS: 0.29%
#
# === model_hs32_lr0.01_nl1_bs64_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00218 rad | 0.12° | NRMS: 0.46%
# Val   RMS: 0.00315 rad | 0.18° | NRMS: 0.61%
#
# === model_hs32_lr0.01_nl1_bs64_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00310 rad | 0.18° | NRMS: 0.66%
# Val   RMS: 0.00384 rad | 0.22° | NRMS: 0.74%
#
# === model_hs32_lr0.01_nl1_bs64_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00272 rad | 0.16° | NRMS: 0.58%
# Val   RMS: 0.00314 rad | 0.18° | NRMS: 0.61%
#
# === model_hs32_lr0.01_nl1_bs64_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00199 rad | 0.11° | NRMS: 0.42%
# Val   RMS: 0.00269 rad | 0.15° | NRMS: 0.52%
#
# === model_hs32_lr0.01_nl2_bs128_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.11105 rad | 6.36° | NRMS: 23.65%
# Val   RMS: 0.12092 rad | 6.93° | NRMS: 23.39%
#
# === model_hs32_lr0.01_nl2_bs128_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.57683 rad | 33.05° | NRMS: 122.85%
# Val   RMS: 0.58679 rad | 33.62° | NRMS: 113.49%
#
# === model_hs32_lr0.01_nl2_bs128_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00299 rad | 0.17° | NRMS: 0.64%
# Val   RMS: 0.00328 rad | 0.19° | NRMS: 0.63%
#
# === model_hs32_lr0.01_nl2_bs128_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.01185 rad | 0.68° | NRMS: 2.52%
# Val   RMS: 0.01521 rad | 0.87° | NRMS: 2.94%
#
# === model_hs32_lr0.01_nl2_bs128_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.21444 rad | 12.29° | NRMS: 45.67%
# Val   RMS: 0.21804 rad | 12.49° | NRMS: 42.17%
#
# === model_hs32_lr0.01_nl2_bs128_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00277 rad | 0.16° | NRMS: 0.59%
# Val   RMS: 0.00387 rad | 0.22° | NRMS: 0.75%
#
# === model_hs32_lr0.01_nl2_bs128_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.05931 rad | 3.40° | NRMS: 12.63%
# Val   RMS: 0.06782 rad | 3.89° | NRMS: 13.12%
#
# === model_hs32_lr0.01_nl2_bs128_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.33724 rad | 19.32° | NRMS: 71.82%
# Val   RMS: 0.35380 rad | 20.27° | NRMS: 68.42%
#
# === model_hs32_lr0.01_nl2_bs128_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00371 rad | 0.21° | NRMS: 0.79%
# Val   RMS: 0.00425 rad | 0.24° | NRMS: 0.82%
#
# === model_hs32_lr0.01_nl2_bs128_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.01251 rad | 0.72° | NRMS: 2.66%
# Val   RMS: 0.01499 rad | 0.86° | NRMS: 2.90%
#
# === model_hs32_lr0.01_nl2_bs128_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.10781 rad | 6.18° | NRMS: 22.96%
# Val   RMS: 0.11829 rad | 6.78° | NRMS: 22.88%
#
# === model_hs32_lr0.01_nl2_bs128_sl15_ep200_bi1_do0.pt ===
# Train RMS: 0.00191 rad | 0.11° | NRMS: 0.41%
# Val   RMS: 0.00257 rad | 0.15° | NRMS: 0.50%
#
# === model_hs32_lr0.01_nl2_bs128_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.11999 rad | 6.88° | NRMS: 25.56%
# Val   RMS: 0.12802 rad | 7.34° | NRMS: 24.76%
#
# === model_hs32_lr0.01_nl2_bs128_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.27933 rad | 16.00° | NRMS: 59.50%
# Val   RMS: 0.30496 rad | 17.47° | NRMS: 58.98%
#
# === model_hs32_lr0.01_nl2_bs128_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00175 rad | 0.10° | NRMS: 0.37%
# Val   RMS: 0.00214 rad | 0.12° | NRMS: 0.41%
#
# === model_hs32_lr0.01_nl2_bs128_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.05882 rad | 3.37° | NRMS: 12.53%
# Val   RMS: 0.06315 rad | 3.62° | NRMS: 12.21%
#
# === model_hs32_lr0.01_nl2_bs128_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.19561 rad | 11.21° | NRMS: 41.67%
# Val   RMS: 0.21083 rad | 12.08° | NRMS: 40.78%
#
# === model_hs32_lr0.01_nl2_bs128_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00259 rad | 0.15° | NRMS: 0.55%
# Val   RMS: 0.00317 rad | 0.18° | NRMS: 0.61%
#
# === model_hs32_lr0.01_nl2_bs64_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.12059 rad | 6.91° | NRMS: 25.68%
# Val   RMS: 0.12620 rad | 7.23° | NRMS: 24.41%
#
# === model_hs32_lr0.01_nl2_bs64_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.22379 rad | 12.82° | NRMS: 47.66%
# Val   RMS: 0.24509 rad | 14.04° | NRMS: 47.40%
#
# === model_hs32_lr0.01_nl2_bs64_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00300 rad | 0.17° | NRMS: 0.64%
# Val   RMS: 0.00341 rad | 0.20° | NRMS: 0.66%
#
# === model_hs32_lr0.01_nl2_bs64_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.03778 rad | 2.16° | NRMS: 8.05%
# Val   RMS: 0.04365 rad | 2.50° | NRMS: 8.44%
#
# === model_hs32_lr0.01_nl2_bs64_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.16444 rad | 9.42° | NRMS: 35.02%
# Val   RMS: 0.17815 rad | 10.21° | NRMS: 34.46%
#
# === model_hs32_lr0.01_nl2_bs64_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00440 rad | 0.25° | NRMS: 0.94%
# Val   RMS: 0.00524 rad | 0.30° | NRMS: 1.01%
#
# === model_hs32_lr0.01_nl2_bs64_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.14495 rad | 8.31° | NRMS: 30.87%
# Val   RMS: 0.15175 rad | 8.69° | NRMS: 29.35%
#
# === model_hs32_lr0.01_nl2_bs64_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.22160 rad | 12.70° | NRMS: 47.19%
# Val   RMS: 0.23949 rad | 13.72° | NRMS: 46.31%
#
# === model_hs32_lr0.01_nl2_bs64_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00206 rad | 0.12° | NRMS: 0.44%
# Val   RMS: 0.00246 rad | 0.14° | NRMS: 0.48%
#
# === model_hs32_lr0.01_nl2_bs64_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.03123 rad | 1.79° | NRMS: 6.65%
# Val   RMS: 0.03531 rad | 2.02° | NRMS: 6.83%
#
# === model_hs32_lr0.01_nl2_bs64_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.25317 rad | 14.51° | NRMS: 53.92%
# Val   RMS: 0.26285 rad | 15.06° | NRMS: 50.83%
#
# === model_hs32_lr0.01_nl2_bs64_sl15_ep200_bi1_do0.pt ===
# Train RMS: 0.00335 rad | 0.19° | NRMS: 0.71%
# Val   RMS: 0.00389 rad | 0.22° | NRMS: 0.75%
#
# === model_hs32_lr0.01_nl2_bs64_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.23290 rad | 13.34° | NRMS: 49.61%
# Val   RMS: 0.23674 rad | 13.56° | NRMS: 45.79%
#
# === model_hs32_lr0.01_nl2_bs64_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.26405 rad | 15.13° | NRMS: 56.24%
# Val   RMS: 0.28568 rad | 16.37° | NRMS: 55.26%
#
# === model_hs32_lr0.01_nl2_bs64_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00291 rad | 0.17° | NRMS: 0.62%
# Val   RMS: 0.00356 rad | 0.20° | NRMS: 0.69%
#
# === model_hs32_lr0.01_nl2_bs64_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.10084 rad | 5.78° | NRMS: 21.48%
# Val   RMS: 0.10559 rad | 6.05° | NRMS: 20.42%
#
# === model_hs32_lr0.01_nl2_bs64_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.21494 rad | 12.32° | NRMS: 45.78%
# Val   RMS: 0.22246 rad | 12.75° | NRMS: 43.03%
#
# === model_hs32_lr0.01_nl2_bs64_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00361 rad | 0.21° | NRMS: 0.77%
# Val   RMS: 0.00384 rad | 0.22° | NRMS: 0.74%
#
# === model_hs64_lr0.01_nl1_bs128_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00175 rad | 0.10° | NRMS: 0.37%
# Val   RMS: 0.00205 rad | 0.12° | NRMS: 0.40%
#
# === model_hs64_lr0.01_nl1_bs128_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00135 rad | 0.08° | NRMS: 0.29%
# Val   RMS: 0.00169 rad | 0.10° | NRMS: 0.33%
#
# === model_hs64_lr0.01_nl1_bs128_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00142 rad | 0.08° | NRMS: 0.30%
# Val   RMS: 0.00172 rad | 0.10° | NRMS: 0.33%
#
# === model_hs64_lr0.01_nl1_bs128_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00152 rad | 0.09° | NRMS: 0.32%
# Val   RMS: 0.00198 rad | 0.11° | NRMS: 0.38%
#
# === model_hs64_lr0.01_nl1_bs128_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00237 rad | 0.14° | NRMS: 0.50%
# Val   RMS: 0.00264 rad | 0.15° | NRMS: 0.51%
#
# === model_hs64_lr0.01_nl1_bs128_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00274 rad | 0.16° | NRMS: 0.58%
# Val   RMS: 0.00313 rad | 0.18° | NRMS: 0.61%
#
# === model_hs64_lr0.01_nl1_bs128_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00139 rad | 0.08° | NRMS: 0.30%
# Val   RMS: 0.00162 rad | 0.09° | NRMS: 0.31%
#
# === model_hs64_lr0.01_nl1_bs128_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00142 rad | 0.08° | NRMS: 0.30%
# Val   RMS: 0.00162 rad | 0.09° | NRMS: 0.31%
#
# === model_hs64_lr0.01_nl1_bs128_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00153 rad | 0.09° | NRMS: 0.33%
# Val   RMS: 0.00186 rad | 0.11° | NRMS: 0.36%
#
# === model_hs64_lr0.01_nl1_bs128_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00174 rad | 0.10° | NRMS: 0.37%
# Val   RMS: 0.00251 rad | 0.14° | NRMS: 0.49%
#
# === model_hs64_lr0.01_nl1_bs128_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00186 rad | 0.11° | NRMS: 0.40%
# Val   RMS: 0.00227 rad | 0.13° | NRMS: 0.44%
#
# === model_hs64_lr0.01_nl1_bs128_sl15_ep200_bi1_do0.pt ===
# Train RMS: 0.00151 rad | 0.09° | NRMS: 0.32%
# Val   RMS: 0.00186 rad | 0.11° | NRMS: 0.36%
#
# === model_hs64_lr0.01_nl1_bs128_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00113 rad | 0.06° | NRMS: 0.24%
# Val   RMS: 0.00138 rad | 0.08° | NRMS: 0.27%
#
# === model_hs64_lr0.01_nl1_bs128_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00185 rad | 0.11° | NRMS: 0.39%
# Val   RMS: 0.00259 rad | 0.15° | NRMS: 0.50%
#
# === model_hs64_lr0.01_nl1_bs128_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00157 rad | 0.09° | NRMS: 0.33%
# Val   RMS: 0.00200 rad | 0.11° | NRMS: 0.39%
#
# === model_hs64_lr0.01_nl1_bs128_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00152 rad | 0.09° | NRMS: 0.32%
# Val   RMS: 0.00184 rad | 0.11° | NRMS: 0.36%
#
# === model_hs64_lr0.01_nl1_bs128_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00160 rad | 0.09° | NRMS: 0.34%
# Val   RMS: 0.00214 rad | 0.12° | NRMS: 0.41%
#
# === model_hs64_lr0.01_nl1_bs128_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00336 rad | 0.19° | NRMS: 0.71%
# Val   RMS: 0.00397 rad | 0.23° | NRMS: 0.77%
#
# === model_hs64_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00124 rad | 0.07° | NRMS: 0.26%
# Val   RMS: 0.00145 rad | 0.08° | NRMS: 0.28%
#
# === model_hs64_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00196 rad | 0.11° | NRMS: 0.42%
# Val   RMS: 0.00217 rad | 0.12° | NRMS: 0.42%
#
# === model_hs64_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00228 rad | 0.13° | NRMS: 0.49%
# Val   RMS: 0.00252 rad | 0.14° | NRMS: 0.49%
#
# === model_hs64_lr0.01_nl1_bs64_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00274 rad | 0.16° | NRMS: 0.58%
# Val   RMS: 0.00347 rad | 0.20° | NRMS: 0.67%
#
# === model_hs64_lr0.01_nl1_bs64_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00267 rad | 0.15° | NRMS: 0.57%
# Val   RMS: 0.00296 rad | 0.17° | NRMS: 0.57%
#
# === model_hs64_lr0.01_nl1_bs64_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00176 rad | 0.10° | NRMS: 0.37%
# Val   RMS: 0.00253 rad | 0.15° | NRMS: 0.49%
#
# === model_hs64_lr0.01_nl1_bs64_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00153 rad | 0.09° | NRMS: 0.33%
# Val   RMS: 0.00183 rad | 0.10° | NRMS: 0.35%
#
# === model_hs64_lr0.01_nl1_bs64_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00206 rad | 0.12° | NRMS: 0.44%
# Val   RMS: 0.00250 rad | 0.14° | NRMS: 0.48%
#
# === model_hs64_lr0.01_nl1_bs64_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00212 rad | 0.12° | NRMS: 0.45%
# Val   RMS: 0.00238 rad | 0.14° | NRMS: 0.46%
#
# === model_hs64_lr0.01_nl1_bs64_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00185 rad | 0.11° | NRMS: 0.39%
# Val   RMS: 0.00226 rad | 0.13° | NRMS: 0.44%
#
# === model_hs64_lr0.01_nl1_bs64_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00197 rad | 0.11° | NRMS: 0.42%
# Val   RMS: 0.00244 rad | 0.14° | NRMS: 0.47%
#
# === model_hs64_lr0.01_nl1_bs64_sl15_ep200_bi1_do0.pt ===
# Train RMS: 0.00290 rad | 0.17° | NRMS: 0.62%
# Val   RMS: 0.00337 rad | 0.19° | NRMS: 0.65%
#
# === model_hs64_lr0.01_nl1_bs64_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.00149 rad | 0.09° | NRMS: 0.32%
# Val   RMS: 0.00174 rad | 0.10° | NRMS: 0.34%
#
# === model_hs64_lr0.01_nl1_bs64_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.00221 rad | 0.13° | NRMS: 0.47%
# Val   RMS: 0.00245 rad | 0.14° | NRMS: 0.47%
#
# === model_hs64_lr0.01_nl1_bs64_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00176 rad | 0.10° | NRMS: 0.38%
# Val   RMS: 0.00212 rad | 0.12° | NRMS: 0.41%
#
# === model_hs64_lr0.01_nl1_bs64_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00187 rad | 0.11° | NRMS: 0.40%
# Val   RMS: 0.00258 rad | 0.15° | NRMS: 0.50%
#
# === model_hs64_lr0.01_nl1_bs64_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00278 rad | 0.16° | NRMS: 0.59%
# Val   RMS: 0.00308 rad | 0.18° | NRMS: 0.60%
#
# === model_hs64_lr0.01_nl1_bs64_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00260 rad | 0.15° | NRMS: 0.55%
# Val   RMS: 0.00333 rad | 0.19° | NRMS: 0.64%
#
# === model_hs64_lr0.01_nl2_bs128_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.04793 rad | 2.75° | NRMS: 10.21%
# Val   RMS: 0.05313 rad | 3.04° | NRMS: 10.27%
#
# === model_hs64_lr0.01_nl2_bs128_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.24167 rad | 13.85° | NRMS: 51.47%
# Val   RMS: 0.25507 rad | 14.61° | NRMS: 49.33%
#
# === model_hs64_lr0.01_nl2_bs128_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00219 rad | 0.13° | NRMS: 0.47%
# Val   RMS: 0.00250 rad | 0.14° | NRMS: 0.48%
#
# === model_hs64_lr0.01_nl2_bs128_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00713 rad | 0.41° | NRMS: 1.52%
# Val   RMS: 0.00917 rad | 0.53° | NRMS: 1.77%
#
# === model_hs64_lr0.01_nl2_bs128_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.21024 rad | 12.05° | NRMS: 44.78%
# Val   RMS: 0.21256 rad | 12.18° | NRMS: 41.11%
#
# === model_hs64_lr0.01_nl2_bs128_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00282 rad | 0.16° | NRMS: 0.60%
# Val   RMS: 0.00331 rad | 0.19° | NRMS: 0.64%
#
# === model_hs64_lr0.01_nl2_bs128_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.02158 rad | 1.24° | NRMS: 4.59%
# Val   RMS: 0.02388 rad | 1.37° | NRMS: 4.62%
#
# === model_hs64_lr0.01_nl2_bs128_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.19848 rad | 11.37° | NRMS: 42.27%
# Val   RMS: 0.21347 rad | 12.23° | NRMS: 41.28%
#
# === model_hs64_lr0.01_nl2_bs128_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00228 rad | 0.13° | NRMS: 0.49%
# Val   RMS: 0.00264 rad | 0.15° | NRMS: 0.51%
#
# === model_hs64_lr0.01_nl2_bs128_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00397 rad | 0.23° | NRMS: 0.85%
# Val   RMS: 0.00554 rad | 0.32° | NRMS: 1.07%
#
# === model_hs64_lr0.01_nl2_bs128_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.00584 rad | 0.33° | NRMS: 1.24%
# Val   RMS: 0.00904 rad | 0.52° | NRMS: 1.75%
#
# === model_hs64_lr0.01_nl2_bs128_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.14124 rad | 8.09° | NRMS: 30.08%
# Val   RMS: 0.14617 rad | 8.37° | NRMS: 28.27%
#
# === model_hs64_lr0.01_nl2_bs128_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.25365 rad | 14.53° | NRMS: 54.03%
# Val   RMS: 0.27440 rad | 15.72° | NRMS: 53.07%
#
# === model_hs64_lr0.01_nl2_bs128_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00412 rad | 0.24° | NRMS: 0.88%
# Val   RMS: 0.00440 rad | 0.25° | NRMS: 0.85%
#
# === model_hs64_lr0.01_nl2_bs128_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00538 rad | 0.31° | NRMS: 1.15%
# Val   RMS: 0.00654 rad | 0.37° | NRMS: 1.27%
#
# === model_hs64_lr0.01_nl2_bs128_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.06469 rad | 3.71° | NRMS: 13.78%
# Val   RMS: 0.06661 rad | 3.82° | NRMS: 12.88%
#
# === model_hs64_lr0.01_nl2_bs128_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00283 rad | 0.16° | NRMS: 0.60%
# Val   RMS: 0.00327 rad | 0.19° | NRMS: 0.63%
#
# === model_hs64_lr0.01_nl2_bs64_sl10_ep200_bi0_do0.2.pt ===
# Train RMS: 0.06072 rad | 3.48° | NRMS: 12.93%
# Val   RMS: 0.06754 rad | 3.87° | NRMS: 13.06%
#
# === model_hs64_lr0.01_nl2_bs64_sl10_ep200_bi0_do0.5.pt ===
# Train RMS: 0.23095 rad | 13.23° | NRMS: 49.19%
# Val   RMS: 0.24922 rad | 14.28° | NRMS: 48.20%
#
# === model_hs64_lr0.01_nl2_bs64_sl10_ep200_bi0_do0.pt ===
# Train RMS: 0.00370 rad | 0.21° | NRMS: 0.79%
# Val   RMS: 0.00419 rad | 0.24° | NRMS: 0.81%
#
# === model_hs64_lr0.01_nl2_bs64_sl10_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00596 rad | 0.34° | NRMS: 1.27%
# Val   RMS: 0.00805 rad | 0.46° | NRMS: 1.56%
#
# === model_hs64_lr0.01_nl2_bs64_sl10_ep200_bi1_do0.5.pt ===
# Train RMS: 0.11015 rad | 6.31° | NRMS: 23.46%
# Val   RMS: 0.11271 rad | 6.46° | NRMS: 21.80%
#
# === model_hs64_lr0.01_nl2_bs64_sl10_ep200_bi1_do0.pt ===
# Train RMS: 0.00287 rad | 0.16° | NRMS: 0.61%
# Val   RMS: 0.00331 rad | 0.19° | NRMS: 0.64%
#
# === model_hs64_lr0.01_nl2_bs64_sl15_ep200_bi0_do0.2.pt ===
# Train RMS: 0.10357 rad | 5.93° | NRMS: 22.06%
# Val   RMS: 0.11089 rad | 6.35° | NRMS: 21.45%
#
# === model_hs64_lr0.01_nl2_bs64_sl15_ep200_bi0_do0.5.pt ===
# Train RMS: 0.11411 rad | 6.54° | NRMS: 24.30%
# Val   RMS: 0.13222 rad | 7.58° | NRMS: 25.57%
#
# === model_hs64_lr0.01_nl2_bs64_sl15_ep200_bi0_do0.pt ===
# Train RMS: 0.00424 rad | 0.24° | NRMS: 0.90%
# Val   RMS: 0.00480 rad | 0.27° | NRMS: 0.93%
#
# === model_hs64_lr0.01_nl2_bs64_sl15_ep200_bi1_do0.2.pt ===
# Train RMS: 0.00730 rad | 0.42° | NRMS: 1.55%
# Val   RMS: 0.00854 rad | 0.49° | NRMS: 1.65%
#
# === model_hs64_lr0.01_nl2_bs64_sl15_ep200_bi1_do0.5.pt ===
# Train RMS: 0.07915 rad | 4.53° | NRMS: 16.86%
# Val   RMS: 0.09093 rad | 5.21° | NRMS: 17.58%
#
# === model_hs64_lr0.01_nl2_bs64_sl15_ep200_bi1_do0.pt ===
# Train RMS: 0.00319 rad | 0.18° | NRMS: 0.68%
# Val   RMS: 0.00396 rad | 0.23° | NRMS: 0.76%
#
# === model_hs64_lr0.01_nl2_bs64_sl5_ep200_bi0_do0.2.pt ===
# Train RMS: 0.10073 rad | 5.77° | NRMS: 21.46%
# Val   RMS: 0.10878 rad | 6.23° | NRMS: 21.04%
#
# === model_hs64_lr0.01_nl2_bs64_sl5_ep200_bi0_do0.5.pt ===
# Train RMS: 0.23216 rad | 13.30° | NRMS: 49.45%
# Val   RMS: 0.25047 rad | 14.35° | NRMS: 48.45%
#
# === model_hs64_lr0.01_nl2_bs64_sl5_ep200_bi0_do0.pt ===
# Train RMS: 0.00341 rad | 0.20° | NRMS: 0.73%
# Val   RMS: 0.00394 rad | 0.23° | NRMS: 0.76%
#
# === model_hs64_lr0.01_nl2_bs64_sl5_ep200_bi1_do0.2.pt ===
# Train RMS: 0.01133 rad | 0.65° | NRMS: 2.41%
# Val   RMS: 0.01377 rad | 0.79° | NRMS: 2.66%
#
# === model_hs64_lr0.01_nl2_bs64_sl5_ep200_bi1_do0.5.pt ===
# Train RMS: 0.16783 rad | 9.62° | NRMS: 35.75%
# Val   RMS: 0.17210 rad | 9.86° | NRMS: 33.29%
#
# === model_hs64_lr0.01_nl2_bs64_sl5_ep200_bi1_do0.pt ===
# Train RMS: 0.00386 rad | 0.22° | NRMS: 0.82%
# Val   RMS: 0.00439 rad | 0.25° | NRMS: 0.85%
#
# === Top 5 Models by Validation RMS (Theta) ===
#
# #1: model_hs64_lr0.01_nl1_bs128_sl5_ep200_bi0_do0.2.pt
#   Train RMS: 0.00113 rad | 0.06° | NRMS: 0.24%
#   Val   RMS: 0.00138 rad | 0.08° | NRMS: 0.27%
#
# #2: model_hs64_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.2.pt
#   Train RMS: 0.00124 rad | 0.07° | NRMS: 0.26%
#   Val   RMS: 0.00145 rad | 0.08° | NRMS: 0.28%
#
# #3: model_hs32_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.pt
#   Train RMS: 0.00123 rad | 0.07° | NRMS: 0.26%
#   Val   RMS: 0.00146 rad | 0.08° | NRMS: 0.28%
#
# #4: model_hs32_lr0.01_nl1_bs64_sl5_ep200_bi0_do0.5.pt
#   Train RMS: 0.00122 rad | 0.07° | NRMS: 0.26%
#   Val   RMS: 0.00152 rad | 0.09° | NRMS: 0.29%
#
# #5: model_hs32_lr0.01_nl1_bs128_sl10_ep200_bi0_do0.5.pt
#   Train RMS: 0.00122 rad | 0.07° | NRMS: 0.26%
#   Val   RMS: 0.00160 rad | 0.09° | NRMS: 0.31%

# %%
# Top 5 by Validation RMS (Theta)
top_5 = sorted(model_stats, key=lambda x: x['train_rms'])[:5]

print("\n=== Top 5 Models by Validation RMS (Theta) ===")
for i, stat in enumerate(top_5, 1):
    print(f"\n#{i}: {stat['model_file']}")
    print(f"  Train RMS: {stat['train_rms']:.5f} rad | {stat['train_deg']:.2f}° | NRMS: {stat['train_nrms']:.2f}%")
    print(f"  Val   RMS: {stat['val_rms']:.5f} rad | {stat['val_deg']:.2f}° | NRMS: {stat['val_nrms']:.2f}%")
# Out:
# === Top 5 Models by Validation RMS (Theta) ===
#
# #1: model_hs64_lr0.01_nl1_bs128_sl5_ep200_bi0_do0.2.pt
#   Train RMS: 0.00113 rad | 0.06° | NRMS: 0.24%
#   Val   RMS: 0.00138 rad | 0.08° | NRMS: 0.27%
#
# #2: model_hs32_lr0.01_nl1_bs128_sl10_ep200_bi0_do0.5.pt
#   Train RMS: 0.00122 rad | 0.07° | NRMS: 0.26%
#   Val   RMS: 0.00160 rad | 0.09° | NRMS: 0.31%
#
# #3: model_hs32_lr0.01_nl1_bs64_sl5_ep200_bi0_do0.5.pt
#   Train RMS: 0.00122 rad | 0.07° | NRMS: 0.26%
#   Val   RMS: 0.00152 rad | 0.09° | NRMS: 0.29%
#
# #4: model_hs32_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.pt
#   Train RMS: 0.00123 rad | 0.07° | NRMS: 0.26%
#   Val   RMS: 0.00146 rad | 0.08° | NRMS: 0.28%
#
# #5: model_hs64_lr0.01_nl1_bs64_sl10_ep200_bi0_do0.2.pt
#   Train RMS: 0.00124 rad | 0.07° | NRMS: 0.26%
#   Val   RMS: 0.00145 rad | 0.08° | NRMS: 0.28%
