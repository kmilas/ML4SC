# %%
import numpy as np
from gym_unbalanced_disk import UnbalancedDisk
import gymnasium as gym
from gymnasium import spaces

class AC_UnbalancedDisk(UnbalancedDisk):
    def __init__(self, umax=3., dt = 0.025, render_mode='human'):
        super().__init__(umax=umax, dt=dt, render_mode=render_mode)

        #self.actions_values = np.linspace(-self.umax, self.umax, self.num_actions)
        #self.action_space = spaces.Discrete(self.num_actions)
        self.target = np.pi
        low = [-np.pi,-40] 
        high = [np.pi,40]
        self.observation_space = spaces.Box(low=np.array(low,dtype=np.float32),high=np.array(high,dtype=np.float32),shape=(2,))
    
    def step(self,action):
        #discrete_action = self.actions_values[np.abs(action - self.actions_values).argmin()]
        obs, reward, terminated, truncated, info = super().step(action)

        ### setup our reward
        th = obs[0]
        omega = obs[1]
        norm_theta = (th)%(2*np.pi) #- np.pi
        error = abs(self.target-abs(norm_theta))
        if abs(norm_theta)< np.pi/2:
           reward = np.min([-0.5, -5 + abs(omega)])
        else:
           reward = abs(norm_theta)**3/(1 + abs(omega)*2)
        #             if abs(error)> np.pi/4:
        #    reward = 0.1*np.sign(error)*omega
        #else:
        # reward = - norm_theta**2 -0.1*(omega / (1 + 10*abs(norm_theta)))**2 - 0.01*action**2# try np.exp 
        ### discritize obs if we use Q learning
        return obs, reward, terminated, truncated, info
    
    def reset(self, seed=None, options=None):
        obs, info = super().reset()

        return obs, info

# %%
from gymnasium.wrappers import TimeLimit
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import StopTrainingOnMaxEpisodes

# %%
env = AC_UnbalancedDisk()
env = TimeLimit(env, max_episode_steps=500)
env = Monitor(env)
stop_cb = StopTrainingOnMaxEpisodes(max_episodes=100, verbose=1)

model = PPO(
    policy='MlpPolicy',
    env=env,
    learning_rate=1e-3,
    verbose=1,
)

model.learn(
    total_timesteps=1_000_000,  
    callback=stop_cb,
)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | 2.38e+04 |
# | time/              |          |
# |    fps             | 905      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 2.68e+04    |
# | time/                   |             |
# |    fps                  | 665         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005776522 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.000172   |
# |    learning_rate        | 0.001       |
# |    loss                 | 4.15e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.99        |
# |    value_loss           | 7.57e+05    |
# -----------------------------------------

# %%
env = AC_UnbalancedDisk()
obs, _ = env.reset()
for i in range(5000):
    action, _states = model.predict(obs)  # policy
    obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    t = (obs[0] + np.pi)%(2*np.pi) 
    print( f'theta = {t: .4f}, omega: {obs[1]: .4f}')
    if terminated or truncated:
        obs, _ = env.reset()
    
env.close()
# Out:
# theta =  3.1412, omega: -0.2649
# theta =  3.1340, omega: -0.1672
# theta =  3.1311, omega: -0.0987
# theta =  3.1323, omega:  0.1480
# theta =  3.1309, omega: -0.1320
# theta =  3.1274, omega: -0.1519
# theta =  3.1237, omega: -0.1695
# theta =  3.1189, omega: -0.2659
# theta =  3.1163, omega:  0.0334
# theta =  3.1179, omega: -0.0200
# theta =  3.1158, omega:  0.0026
# theta =  3.1159, omega: -0.1299
# theta =  3.1095, omega: -0.3568
# theta =  3.1006, omega: -0.1856
# theta =  3.0981, omega: -0.0624
# theta =  3.0938, omega: -0.3239
# theta =  3.0850, omega: -0.2973
# theta =  3.0816, omega: -0.0265
# theta =  3.0812, omega:  0.0103
# theta =  3.0785, omega: -0.2069
# theta =  3.0756, omega: -0.1076
# theta =  3.0713, omega: -0.0345
# theta =  3.0734, omega:  0.1144
# theta =  3.0764, omega: -0.0002
# theta =  3.0751, omega:  0.0003
# theta =  3.0750, omega: -0.0012
# theta =  3.0782, omega:  0.2012
# theta =  3.0792, omega: -0.0047
# theta =  3.0789, omega: -0.0430
# theta =  3.0783, omega:  0.0001
# theta =  3.0780, omega:  0.0297
# theta =  3.0794, omega:  0.0009
# theta =  3.0785, omega:  0.0004
# theta =  3.0774, omega:  0.0019
# theta =  3.0777, omega: -0.0016
# theta =  3.0801, omega:  0.0012
# theta =  3.0791, omega: -0.0004
# theta =  3.0768, omega: -0.1765
# theta =  3.0740, omega: -0.0001
# theta =  3.0729, omega: -0.0667
# theta =  3.0768, omega:  0.3124
# theta =  3.0788, omega: -0.0875
# theta =  3.0783, omega:  0.0008
# theta =  3.0790, omega: -0.0175
# theta =  3.0794, omega: -0.0009
# theta =  3.0804, omega:  0.0002
# theta =  3.0773, omega: -0.0036
# theta =  3.0797, omega:  0.0350
# theta =  3.0808, omega:  0.1422
# theta =  3.0803, omega: -0.0932
# theta =  3.0760, omega: -0.1856
# theta =  3.0767, omega:  0.0598
# theta =  3.0772, omega: -0.0058
# theta =  3.0770, omega:  0.0384
# theta =  3.0762, omega: -0.1333
# theta =  3.0764, omega:  0.0004
# theta =  3.0749, omega:  0.0044
# theta =  3.0737, omega:  0.0008
# theta =  3.0729, omega: -0.1550
# theta =  3.0725, omega:  0.0832
# theta =  3.0770, omega:  0.1993
# theta =  3.0820, omega:  0.2370
# theta =  3.0829, omega: -0.0339
# theta =  3.0826, omega: -0.0251
# theta =  3.0835, omega:  0.0004
# theta =  3.0826, omega:  0.0014
# theta =  3.0811, omega:  0.0021
# theta =  3.0823, omega:  0.0107
# theta =  3.0828, omega:  0.0016
# theta =  3.0829, omega: -0.0001
# theta =  3.0829, omega:  0.0004
# theta =  3.0814, omega: -0.0007
# theta =  3.0824, omega: -0.0709
# theta =  3.0809, omega:  0.0032
# theta =  3.0834, omega:  0.0781
# theta =  3.0822, omega: -0.0865
# theta =  3.0826, omega: -0.0014
# theta =  3.0804, omega: -0.0539
# theta =  3.0788, omega: -0.0635
# theta =  3.0781, omega: -0.0008
# theta =  3.0779, omega: -0.0024
# theta =  3.0732, omega: -0.3654
# theta =  3.0687, omega: -0.0253
# theta =  3.0710, omega:  0.0409
# theta =  3.0675, omega: -0.0963
# theta =  3.0627, omega: -0.3164
# theta =  3.0615, omega:  0.0648
# theta =  3.0602, omega:  0.0001
# theta =  3.0593, omega: -0.1604
# theta =  3.0569, omega:  0.0012
# theta =  3.0589, omega:  0.0001
# theta =  3.0569, omega: -0.0388
# theta =  3.0558, omega:  0.0006
# theta =  3.0580, omega: -0.0032
# theta =  3.0577, omega:  0.0004
# theta =  3.0571, omega:  0.0022
# theta =  3.0556, omega: -0.0849
# theta =  3.0573, omega:  0.0023
# theta =  3.0539, omega: -0.2866
# theta =  3.0549, omega:  0.2731
# theta =  3.0564, omega:  0.0007
# theta =  3.0567, omega:  0.0006
# theta =  3.0566, omega: -0.0414
# theta =  3.0595, omega:  0.1841
# theta =  3.0573, omega: -0.1904
# theta =  3.0540, omega:  0.0024
# theta =  3.0572, omega:  0.0002
# theta =  3.0562, omega: -0.0024
# theta =  3.0539, omega: -0.0077
# theta =  3.0573, omega:  0.0246
# theta =  3.0580, omega:  0.1280
# theta =  3.0595, omega:  0.1237
# theta =  3.0664, omega:  0.3181
# theta =  3.0703, omega: -0.0117
# theta =  3.0681, omega: -0.0001
# theta =  3.0684, omega: -0.0013
# theta =  3.0694, omega: -0.0012
# theta =  3.0678, omega: -0.0685
# theta =  3.0682, omega:  0.0129
# theta =  3.0673, omega:  0.0006
# theta =  3.0724, omega:  0.2892
# theta =  3.0721, omega: -0.1842
# theta =  3.0719, omega:  0.0033
# theta =  3.0706, omega:  0.0025
# theta =  3.0737, omega:  0.0812
# theta =  3.0710, omega: -0.0024
# theta =  3.0700, omega: -0.2498
# theta =  3.0688, omega:  0.1288
# theta =  3.0719, omega: -0.0007
# theta =  3.0678, omega: -0.0501
# theta =  3.0673, omega: -0.0017
# theta =  3.0689, omega: -0.0025
# theta =  3.0684, omega:  0.0347
# theta =  3.0718, omega:  0.2232
# theta =  3.0760, omega: -0.0005
# theta =  3.0750, omega: -0.0846
# theta =  3.0759, omega:  0.2822
# theta =  3.0797, omega: -0.0650
# theta =  3.0794, omega:  0.1090
# theta =  3.0813, omega:  0.0379
# theta =  3.0784, omega: -0.2626
# theta =  3.0776, omega:  0.0380
# theta =  3.0771, omega: -0.0019
# theta =  3.0743, omega: -0.2992
# theta =  3.0686, omega:  0.0060
# theta =  3.0689, omega:  0.0018
# theta =  3.0690, omega:  0.0004
# theta =  3.0706, omega:  0.1577
# theta =  3.0740, omega: -0.0011
# theta =  3.0729, omega: -0.0011
# theta =  3.0727, omega:  0.0188
# theta =  3.0718, omega: -0.1000
# theta =  3.0700, omega: -0.0179
# theta =  3.0703, omega: -0.0005
# theta =  3.0680, omega: -0.1301
# theta =  3.0668, omega:  0.0401
# theta =  3.0671, omega: -0.0011
# theta =  3.0687, omega:  0.1131
# theta =  3.0762, omega:  0.2503
# theta =  3.0733, omega: -0.1557
# theta =  3.0717, omega: -0.0623
# theta =  3.0713, omega:  0.0001
# theta =  3.0783, omega:  0.4833
# theta =  3.0826, omega: -0.0822
# theta =  3.0827, omega:  0.0005
# theta =  3.0817, omega:  0.0008
# theta =  3.0804, omega: -0.0031
# theta =  3.0841, omega:  0.2004
# theta =  3.0847, omega: -0.0228
# theta =  3.0865, omega:  0.1008
# theta =  3.0884, omega: -0.0584
# theta =  3.0850, omega: -0.1069
# theta =  3.0795, omega: -0.3363
# theta =  3.0692, omega: -0.4459
# theta =  3.0690, omega:  0.2256
# theta =  3.0669, omega: -0.2144
# theta =  3.0606, omega: -0.1669
# theta =  3.0588, omega:  0.0012
# theta =  3.0611, omega:  0.0141
# theta =  3.0631, omega:  0.0004
# theta =  3.0626, omega:  0.1265
# theta =  3.0642, omega:  0.0011
# theta =  3.0636, omega:  0.0027
# theta =  3.0633, omega:  0.0354
# theta =  3.0635, omega: -0.0004
# theta =  3.0636, omega: -0.0020
# theta =  3.0639, omega:  0.0057
# theta =  3.0616, omega: -0.1714
# theta =  3.0571, omega: -0.1040
# theta =  3.0587, omega:  0.0021
# theta =  3.0565, omega: -0.0127
# theta =  3.0585, omega:  0.0019
# theta =  3.0586, omega: -0.0015
# theta =  3.0529, omega: -0.3501
# theta =  3.0495, omega: -0.0654
# theta =  3.0472, omega: -0.0014
# theta =  3.0467, omega:  0.0013
# theta =  3.0484, omega: -0.0002
# theta =  3.0477, omega: -0.0011
# theta =  3.0499, omega:  0.2389
# theta =  3.0512, omega: -0.0662
# theta =  3.0506, omega:  0.0024
# theta =  3.0517, omega:  0.0008
# theta =  3.0511, omega: -0.0752
# theta =  3.0493, omega:  0.0006
# theta =  3.0474, omega: -0.1255
# theta =  3.0429, omega: -0.2381
# theta =  3.0403, omega:  0.0006
# theta =  3.0414, omega:  0.2338
# theta =  3.0470, omega:  0.0354
# theta =  3.0551, omega:  0.6096
# theta =  3.0651, omega:  0.1078
# theta =  3.0646, omega: -0.0019
# theta =  3.0651, omega:  0.0003
# theta =  3.0641, omega:  0.0009
# theta =  3.0646, omega: -0.0001
# theta =  3.0650, omega:  0.0016
# theta =  3.0654, omega: -0.0031
# theta =  3.0642, omega: -0.0014
# theta =  3.0643, omega: -0.0013
# theta =  3.0651, omega:  0.0002
# theta =  3.0667, omega:  0.1486
# theta =  3.0668, omega: -0.1057
# theta =  3.0662, omega:  0.0626
# theta =  3.0674, omega:  0.0005
# theta =  3.0670, omega:  0.0004
# theta =  3.0723, omega:  0.4499
# theta =  3.0746, omega: -0.2767
# theta =  3.0697, omega: -0.1421
# theta =  3.0688, omega: -0.0421
# theta =  3.0692, omega:  0.0658
# theta =  3.0685, omega:  0.0068
# theta =  3.0682, omega: -0.0004
# theta =  3.0684, omega: -0.0457
# theta =  3.0686, omega: -0.0002
# theta =  3.0660, omega:  0.0004
# theta =  3.0646, omega: -0.1846
# theta =  3.0606, omega: -0.1272
# theta =  3.0606, omega:  0.0004
# theta =  3.0600, omega:  0.0012
# theta =  3.0603, omega:  0.0020
# theta =  3.0598, omega:  0.0335
# theta =  3.0603, omega: -0.0014
# theta =  3.0611, omega: -0.0011
# theta =  3.0593, omega:  0.0190
# theta =  3.0624, omega:  0.0007
# theta =  3.0625, omega:  0.2241
# theta =  3.0673, omega:  0.0023
# theta =  3.0660, omega:  0.0020
# theta =  3.0612, omega: -0.2532
# theta =  3.0581, omega: -0.1395
# theta =  3.0576, omega:  0.0024
# theta =  3.0583, omega: -0.0015
# theta =  3.0588, omega:  0.0011
# theta =  3.0581, omega: -0.0017
# theta =  3.0588, omega:  0.0053
# theta =  3.0603, omega:  0.1361
# theta =  3.0638, omega:  0.1087
# theta =  3.0647, omega: -0.0001
# theta =  3.0651, omega: -0.0000
# theta =  3.0634, omega:  0.0002
# theta =  3.0617, omega: -0.1712
# theta =  3.0608, omega:  0.0043
# theta =  3.0532, omega: -0.5275
# theta =  3.0444, omega: -0.2000
# theta =  3.0425, omega:  0.0431
# theta =  3.0504, omega:  0.4447
# theta =  3.0543, omega: -0.0650
# theta =  3.0554, omega:  0.2189
# theta =  3.0611, omega:  0.1271
# theta =  3.0603, omega: -0.0651
# theta =  3.0607, omega: -0.0006
# theta =  3.0592, omega: -0.0707
# theta =  3.0574, omega: -0.1250
# theta =  3.0599, omega:  0.3149
# theta =  3.0595, omega: -0.2555
# theta =  3.0573, omega:  0.0718
# theta =  3.0553, omega: -0.1618
# theta =  3.0586, omega:  0.2108
# theta =  3.0571, omega: -0.0648
# theta =  3.0589, omega: -0.0597
# theta =  3.0573, omega:  0.0273
# theta =  3.0562, omega: -0.0000
# theta =  3.0571, omega: -0.0016
# theta =  3.0548, omega: -0.1774
# theta =  3.0528, omega:  0.0005
# theta =  3.0532, omega: -0.0007
# theta =  3.0550, omega:  0.0004
# theta =  3.0533, omega: -0.0023
# theta =  3.0546, omega:  0.0026
# theta =  3.0529, omega: -0.0005
# theta =  3.0535, omega:  0.0004
# theta =  3.0529, omega:  0.0007
# theta =  3.0528, omega:  0.0010
# theta =  3.0553, omega:  0.1081
# theta =  3.0540, omega: -0.1516
# theta =  3.0529, omega:  0.0923
# theta =  3.0520, omega: -0.1203
# theta =  3.0557, omega:  0.1420
# theta =  3.0566, omega:  0.1901
# theta =  3.0583, omega: -0.1048
# theta =  3.0568, omega:  0.0014
# theta =  3.0567, omega: -0.0013
# theta =  3.0572, omega:  0.0288
# theta =  3.0636, omega:  0.3846
# theta =  3.0682, omega: -0.0315
# theta =  3.0653, omega: -0.1167
# theta =  3.0630, omega: -0.0837
# theta =  3.0636, omega:  0.0412
# theta =  3.0672, omega:  0.2713
# theta =  3.0725, omega:  0.2629
# theta =  3.0759, omega: -0.0037
# theta =  3.0766, omega: -0.0558
# theta =  3.0760, omega:  0.0426
# theta =  3.0748, omega:  0.0008
# theta =  3.0765, omega:  0.0012
# theta =  3.0743, omega: -0.0006
# theta =  3.0805, omega:  0.3359
# theta =  3.0813, omega: -0.0345
# theta =  3.0837, omega: -0.0033
# theta =  3.0819, omega: -0.0741
# theta =  3.0788, omega: -0.0421
# theta =  3.0796, omega: -0.0187
# theta =  3.0787, omega:  0.0086
# theta =  3.0814, omega: -0.0001
# theta =  3.0794, omega: -0.0013
# theta =  3.0758, omega: -0.2042
# theta =  3.0753, omega:  0.0752
# theta =  3.0764, omega: -0.1098
# theta =  3.0764, omega:  0.0117
# theta =  3.0744, omega: -0.0685
# theta =  3.0723, omega: -0.0697
# theta =  3.0732, omega:  0.1749
# theta =  3.0751, omega: -0.0906
# theta =  3.0747, omega:  0.0124
# theta =  3.0745, omega:  0.0710
# theta =  3.0754, omega:  0.0925
# theta =  3.0784, omega: -0.0477
# theta =  3.0762, omega: -0.0811
# theta =  3.0757, omega:  0.1092
# theta =  3.0752, omega: -0.1131
# theta =  3.0734, omega:  0.0311
# theta =  3.0728, omega: -0.1077
# theta =  3.0731, omega: -0.0012
# theta =  3.0731, omega:  0.0016
# theta =  3.0719, omega: -0.1512
# theta =  3.0761, omega:  0.5237
# theta =  3.0839, omega:  0.0241
# theta =  3.0838, omega: -0.0008
# theta =  3.0837, omega: -0.0014
# theta =  3.0835, omega:  0.0008
# theta =  3.0826, omega: -0.0007
# theta =  3.0822, omega: -0.0252
# theta =  3.0818, omega:  0.0006
# theta =  3.0814, omega: -0.1697
# theta =  3.0788, omega:  0.0488
# theta =  3.0833, omega:  0.1241
# theta =  3.0838, omega: -0.0033
# theta =  3.0855, omega: -0.0001
# theta =  3.0823, omega: -0.0009
# theta =  3.0841, omega:  0.0007
# theta =  3.0791, omega: -0.2725
# theta =  3.0743, omega:  0.0081
# theta =  3.0783, omega:  0.0016
# theta =  3.0775, omega: -0.0405
# theta =  3.0728, omega: -0.1368
# theta =  3.0701, omega: -0.0008
# theta =  3.0702, omega: -0.0804
# theta =  3.0709, omega:  0.0007
# theta =  3.0703, omega:  0.0002
# theta =  3.0696, omega: -0.0014
# theta =  3.0714, omega:  0.0008
# theta =  3.0723, omega: -0.0016
# theta =  3.0710, omega: -0.0174
# theta =  3.0668, omega: -0.1106
# theta =  3.0691, omega:  0.0457
# theta =  3.0674, omega: -0.2468
# theta =  3.0616, omega: -0.0588
# theta =  3.0625, omega:  0.0261
# theta =  3.0598, omega: -0.2455
# theta =  3.0538, omega: -0.1825
# theta =  3.0557, omega:  0.3231
# theta =  3.0593, omega: -0.0231
# theta =  3.0608, omega: -0.0013
# theta =  3.0566, omega: -0.0007
# theta =  3.0583, omega: -0.1472
# theta =  3.0567, omega:  0.0079
# theta =  3.0625, omega:  0.3339
# theta =  3.0642, omega: -0.0235
# theta =  3.0648, omega:  0.0076
# theta =  3.0670, omega:  0.1142
# theta =  3.0687, omega:  0.0462
# theta =  3.0703, omega:  0.0038
# theta =  3.0701, omega:  0.0967
# theta =  3.0689, omega: -0.0012
# theta =  3.0712, omega:  0.0006
# theta =  3.0694, omega: -0.0011
# theta =  3.0703, omega:  0.0003
# theta =  3.0693, omega: -0.0750
# theta =  3.0689, omega: -0.0001
# theta =  3.0691, omega:  0.0001
# theta =  3.0661, omega: -0.4052
# theta =  3.0623, omega:  0.0646
# theta =  3.0585, omega: -0.2342
# theta =  3.0563, omega:  0.0458
# theta =  3.0560, omega: -0.0006
# theta =  3.0558, omega: -0.0004
# theta =  3.0572, omega:  0.0009
# theta =  3.0555, omega: -0.1097
# theta =  3.0542, omega: -0.0023
# theta =  3.0500, omega: -0.1644
# theta =  3.0482, omega: -0.0691
# theta =  3.0499, omega:  0.0148
# theta =  3.0489, omega: -0.0116
# theta =  3.0477, omega: -0.0097
# theta =  3.0503, omega:  0.0009
# theta =  3.0501, omega: -0.0013
# theta =  3.0483, omega: -0.0010
# theta =  3.0484, omega: -0.0016
# theta =  3.0474, omega: -0.0361
# theta =  3.0488, omega:  0.0041
# theta =  3.0475, omega: -0.0011
# theta =  3.0467, omega:  0.0009
# theta =  3.0501, omega: -0.0031
# theta =  3.0466, omega:  0.0004
# theta =  3.0451, omega: -0.1749
# theta =  3.0435, omega:  0.0008
# theta =  3.0436, omega: -0.0011
# theta =  3.0466, omega:  0.1996
# theta =  3.0475, omega:  0.0122
# theta =  3.0513, omega: -0.0008
# theta =  3.0484, omega:  0.0012
# theta =  3.0486, omega: -0.0003
# theta =  3.0470, omega: -0.1211
# theta =  3.0478, omega:  0.1119
# theta =  3.0484, omega:  0.0003
# theta =  3.0476, omega: -0.0014
# theta =  3.0511, omega:  0.0082
# theta =  3.0500, omega:  0.0033
# theta =  3.0514, omega:  0.0012
# theta =  3.0501, omega:  0.0007
# theta =  3.0495, omega:  0.0299
# theta =  3.0505, omega: -0.0715
# theta =  3.0474, omega: -0.0003
# theta =  3.0494, omega:  0.0729
# theta =  3.0492, omega:  0.0005
# theta =  3.0500, omega:  0.0020
# theta =  3.0445, omega: -0.2779
# theta =  3.0438, omega:  0.0186
# theta =  3.0430, omega:  0.0008
# theta =  3.0467, omega:  0.1505
# theta =  3.0508, omega:  0.2511
# theta =  3.0522, omega: -0.0590
# theta =  3.0529, omega:  0.1724
# theta =  3.0525, omega: -0.1539
# theta =  3.0527, omega:  0.0335
# theta =  3.0524, omega:  0.0007
# theta =  3.0523, omega: -0.0008
# theta =  3.0562, omega:  0.2521
# theta =  3.0558, omega: -0.1469
# theta =  3.0586, omega:  0.2656
# theta =  3.0549, omega: -0.3675
# theta =  3.0499, omega: -0.0882
# theta =  3.0532, omega:  0.2223
# theta =  3.0518, omega: -0.0181
# theta =  3.0565, omega:  0.1340
# theta =  3.0596, omega:  0.1009
# theta =  3.0570, omega: -0.0809
# theta =  3.0589, omega: -0.0004
# theta =  3.0579, omega:  0.0002
# theta =  3.0569, omega:  0.0020
# theta =  3.0589, omega:  0.0019
# theta =  3.0594, omega: -0.0010
# theta =  3.0576, omega:  0.0002
# theta =  3.0571, omega: -0.0525
# theta =  3.0586, omega:  0.0657
# theta =  3.0569, omega:  0.0010
# theta =  3.0595, omega:  0.0028
# theta =  3.0587, omega:  0.0016
# theta =  3.0594, omega:  0.0002
# theta =  3.0623, omega:  0.2748
# theta =  3.0659, omega: -0.0230
# theta =  3.0645, omega:  0.0329
# theta =  3.0659, omega: -0.0011
# theta =  3.0638, omega:  0.0014
# theta =  3.0677, omega:  0.2308
# theta =  3.0690, omega: -0.0627
# theta =  3.0688, omega:  0.0007
# theta =  3.0699, omega:  0.0334
# theta =  3.0684, omega: -0.0677
# theta =  3.0683, omega: -0.0002
# theta =  3.0639, omega: -0.2322
# theta =  3.0641, omega:  0.0049
# theta =  3.0592, omega: -0.2120
# theta =  3.0619, omega:  0.2227
# theta =  3.0629, omega: -0.1037
# theta =  3.0601, omega:  0.0001
# theta =  3.0602, omega: -0.0014
# theta =  3.0650, omega:  0.2630
# theta =  3.0658, omega: -0.0386
# theta =  3.0670, omega:  0.0649
# theta =  3.0664, omega: -0.0087
# theta =  3.0666, omega: -0.0014
# theta =  3.0668, omega: -0.0280
# theta =  3.0653, omega: -0.1534
# theta =  3.0619, omega: -0.0872
# theta =  3.0595, omega:  0.0014
# theta =  3.0598, omega:  0.0014
# theta =  3.0593, omega: -0.0881
# theta =  3.0573, omega: -0.0466
# theta =  3.0573, omega: -0.0006
# theta =  3.0577, omega:  0.0019
# theta =  3.0584, omega: -0.0189
# theta =  3.0583, omega: -0.0017
# theta =  3.0580, omega:  0.1675
# theta =  3.0622, omega:  0.0446
# theta =  3.0604, omega: -0.0883
# theta =  3.0647, omega:  0.2571
# theta =  3.0692, omega:  0.0598
# theta =  3.0670, omega: -0.0010
# theta =  3.0671, omega: -0.0797
# theta =  3.0647, omega: -0.0012
# theta =  3.0634, omega: -0.1645
# theta =  3.0632, omega: -0.0005
# theta =  3.0631, omega: -0.0014
# theta =  3.0615, omega:  0.0005
# theta =  3.0625, omega:  0.0019
# theta =  3.0596, omega: -0.2792
# theta =  3.0575, omega:  0.0384
# theta =  3.0563, omega:  0.0473
# theta =  3.0581, omega: -0.0017
# theta =  3.0589, omega:  0.0016
# theta =  3.0591, omega: -0.0028
# theta =  3.0597, omega:  0.0006
# theta =  3.0589, omega:  0.0008
# theta =  3.0575, omega:  0.0010
# theta =  3.0579, omega: -0.0006
# theta =  3.0606, omega:  0.0972
# theta =  3.0609, omega:  0.0003
# theta =  3.0624, omega: -0.0009
# theta =  3.0585, omega: -0.1290
# theta =  3.0589, omega:  0.0273
# theta =  3.0586, omega:  0.0025
# theta =  3.0569, omega: -0.1127
# theta =  3.0582, omega:  0.0071
# theta =  3.0580, omega: -0.0001
# theta =  3.0586, omega:  0.1720
# theta =  3.0585, omega: -0.0008
# theta =  3.0601, omega:  0.0017
# theta =  3.0604, omega: -0.0006
# theta =  3.0633, omega:  0.1623
# theta =  3.0604, omega: -0.1428
# theta =  3.0576, omega: -0.2076
# theta =  3.0529, omega:  0.0008
# theta =  3.0554, omega:  0.0016
# theta =  3.0540, omega: -0.0013
# theta =  3.0553, omega: -0.0001
# theta =  3.0511, omega: -0.1609
# theta =  3.0526, omega:  0.0603
# theta =  3.0595, omega:  0.4054
# theta =  3.0602, omega: -0.2352
# theta =  3.0586, omega:  0.0312
# theta =  3.0579, omega:  0.0005
# theta =  3.0558, omega:  0.0009
# theta =  3.0573, omega: -0.1122
# theta =  3.0543, omega: -0.0022
# theta =  3.0551, omega:  0.0015
# theta =  3.0575, omega:  0.1124
# theta =  3.0589, omega:  0.1372
# theta =  3.0599, omega: -0.0663
# theta =  3.0570, omega: -0.0359
# theta =  3.0566, omega: -0.2492
# theta =  3.0550, omega:  0.0200
# theta =  3.0529, omega:  0.0004
# theta =  3.0507, omega:  0.0039
# theta =  3.0531, omega: -0.0011
# theta =  3.0516, omega: -0.0011
# theta =  3.0531, omega: -0.0004
# theta =  3.0543, omega:  0.2795
# theta =  3.0573, omega: -0.0526
# theta =  3.0592, omega:  0.0016
# theta =  3.0575, omega:  0.1101
# theta =  3.0645, omega:  0.1252
# theta =  3.0589, omega: -0.3216
# theta =  3.0519, omega: -0.2123
# theta =  3.0511, omega:  0.0063
# theta =  3.0537, omega:  0.1875
# theta =  3.0551, omega: -0.1161
# theta =  3.0535, omega:  0.0012
# theta =  3.0512, omega: -0.1237
# theta =  3.0502, omega:  0.0064
# theta =  3.0509, omega: -0.0352
# theta =  3.0500, omega: -0.0199
# theta =  3.0500, omega:  0.1329
# theta =  3.0508, omega: -0.0006
# theta =  3.0538, omega: -0.0334
# theta =  3.0544, omega:  0.1939
# theta =  3.0548, omega: -0.0706
# theta =  3.0536, omega:  0.0966
# theta =  3.0558, omega: -0.0330
# theta =  3.0587, omega:  0.2903
# theta =  3.0608, omega: -0.0497
# theta =  3.0608, omega:  0.0116
# theta =  3.0617, omega: -0.0010
# theta =  3.0626, omega: -0.0009
# theta =  3.0607, omega:  0.0006
# theta =  3.0624, omega:  0.0548
# theta =  3.0622, omega:  0.0016
# theta =  3.0619, omega:  0.0006
# theta =  3.0646, omega:  0.0929
# theta =  3.0631, omega: -0.0066
# theta =  3.0634, omega:  0.0004
# theta =  3.0639, omega:  0.0016
# theta =  3.0630, omega:  0.0052
# theta =  3.0650, omega:  0.1338
# theta =  3.0652, omega: -0.1755
# theta =  3.0606, omega: -0.1427
# theta =  3.0585, omega: -0.0006
# theta =  3.0627, omega:  0.2185
# theta =  3.0609, omega: -0.2469
# theta =  3.0608, omega:  0.1168
# theta =  3.0629, omega:  0.1358
# theta =  3.0626, omega: -0.0006
# theta =  3.0648, omega:  0.0247
# theta =  3.0648, omega:  0.0004
# theta =  3.0661, omega:  0.0725
# theta =  3.0665, omega: -0.0000
# theta =  3.0633, omega: -0.2115
# theta =  3.0627, omega:  0.0015
# theta =  3.0598, omega: -0.0904
# theta =  3.0565, omega: -0.0801
# theta =  3.0577, omega:  0.0027
# theta =  3.0576, omega:  0.0001
# theta =  3.0574, omega:  0.0285
# theta =  3.0571, omega: -0.0028
# theta =  3.0555, omega: -0.1202
# theta =  3.0548, omega:  0.1036
# theta =  3.0570, omega:  0.0207
# theta =  3.0614, omega:  0.2031
# theta =  3.0636, omega: -0.0013
# theta =  3.0630, omega: -0.0008
# theta =  3.0614, omega: -0.0604
# theta =  3.0628, omega:  0.0011
# theta =  3.0627, omega:  0.0548
# theta =  3.0635, omega: -0.0002
# theta =  3.0651, omega:  0.0017
# theta =  3.0658, omega: -0.0008
# theta =  3.0638, omega:  0.0024
# theta =  3.0629, omega:  0.0011
# theta =  3.0650, omega:  0.1125
# theta =  3.0650, omega: -0.0009
# theta =  3.0632, omega: -0.0783
# theta =  3.0624, omega: -0.0074
# theta =  3.0624, omega: -0.0004
# theta =  3.0630, omega:  0.0014
# theta =  3.0643, omega:  0.1201
# theta =  3.0652, omega:  0.0004
# theta =  3.0666, omega:  0.0013
# theta =  3.0647, omega: -0.0688
# theta =  3.0647, omega: -0.0229
# theta =  3.0619, omega: -0.0008
# theta =  3.0598, omega: -0.0092
# theta =  3.0624, omega:  0.0022
# theta =  3.0639, omega:  0.1385
# theta =  3.0657, omega: -0.0249
# theta =  3.0651, omega: -0.0995
# theta =  3.0653, omega:  0.1969
# theta =  3.0670, omega: -0.0174
# theta =  3.0692, omega: -0.0437
# theta =  3.0667, omega:  0.0034
# theta =  3.0657, omega: -0.0024
# theta =  3.0652, omega: -0.0329
# theta =  3.0662, omega:  0.0023
# theta =  3.0674, omega:  0.0000
# theta =  3.0671, omega:  0.0002
# theta =  3.0692, omega:  0.3851
# theta =  3.0698, omega: -0.3024
# theta =  3.0702, omega:  0.1063
# theta =  3.0686, omega: -0.0444
# theta =  3.0694, omega: -0.0021
# theta =  3.0683, omega:  0.0019
# theta =  3.0692, omega: -0.0003
# theta =  3.0680, omega: -0.0011
# theta =  3.0694, omega:  0.0000
# theta =  3.0711, omega:  0.0930
# theta =  3.0715, omega:  0.0259
# theta =  3.0726, omega:  0.1240
# theta =  3.0734, omega: -0.1612
# theta =  3.0706, omega:  0.0054
# theta =  3.0746, omega:  0.1090
# theta =  3.0721, omega: -0.2111
# theta =  3.0657, omega: -0.1739
# theta =  3.0602, omega: -0.3080
# theta =  3.0561, omega:  0.0413
# theta =  3.0590, omega:  0.0953
# theta =  3.0616, omega: -0.0036
# theta =  3.0592, omega: -0.0458
# theta =  3.0584, omega:  0.0018
# theta =  3.0574, omega: -0.0598
# theta =  3.0581, omega:  0.0008
# theta =  3.0572, omega: -0.0006
# theta =  3.0569, omega: -0.0564
# theta =  3.0567, omega:  0.0592
# theta =  3.0586, omega:  0.0001
# theta =  3.0575, omega: -0.0617
# theta =  3.0581, omega:  0.2049
# theta =  3.0626, omega:  0.1490
# theta =  3.0637, omega:  0.0208
# theta =  3.0671, omega: -0.0011
# theta =  3.0674, omega:  0.0003
# theta =  3.0654, omega: -0.0313
# theta =  3.0661, omega:  0.0962
# theta =  3.0660, omega: -0.0436
# theta =  3.0668, omega: -0.0007
# theta =  3.0666, omega: -0.0014
# theta =  3.0649, omega: -0.0902
# theta =  3.0619, omega: -0.1604
# theta =  3.0566, omega: -0.1459
# theta =  3.0581, omega:  0.1792
# theta =  3.0612, omega: -0.0217
# theta =  3.0598, omega: -0.0003
# theta =  3.0600, omega:  0.0109
# theta =  3.0606, omega: -0.0000
# theta =  3.0627, omega:  0.0820
# theta =  3.0629, omega:  0.0001
# theta =  3.0641, omega:  0.0060
# theta =  3.0610, omega: -0.0066
# theta =  3.0608, omega: -0.0237
# theta =  3.0625, omega: -0.0010
# theta =  3.0624, omega:  0.0228
# theta =  3.0610, omega:  0.0009
# theta =  3.0615, omega:  0.0005
# theta =  3.0605, omega:  0.0018
# theta =  3.0623, omega: -0.0580
# theta =  3.0607, omega:  0.0004
# theta =  3.0648, omega:  0.2787
# theta =  3.0654, omega: -0.1898
# theta =  3.0664, omega:  0.2121
# theta =  3.0714, omega:  0.2893
# theta =  3.0736, omega: -0.1336
# theta =  3.0681, omega: -0.1842
# theta =  3.0680, omega:  0.0464
# theta =  3.0678, omega:  0.0000
# theta =  3.0690, omega:  0.0004
# theta =  3.0656, omega: -0.2349
# theta =  3.0646, omega:  0.0133
# theta =  3.0640, omega:  0.0002
# theta =  3.0637, omega: -0.0003
# theta =  3.0566, omega: -0.4071
# theta =  3.0515, omega: -0.0348
# theta =  3.0545, omega:  0.0000
# theta =  3.0533, omega:  0.0016
# theta =  3.0529, omega:  0.0023
# theta =  3.0532, omega: -0.0009
# theta =  3.0560, omega:  0.1881
# theta =  3.0555, omega: -0.0571
# theta =  3.0544, omega: -0.2113
# theta =  3.0531, omega:  0.2067
# theta =  3.0545, omega: -0.0001
# theta =  3.0583, omega:  0.3447
# theta =  3.0662, omega:  0.2401
# theta =  3.0739, omega:  0.2278
# theta =  3.0759, omega:  0.0071
# theta =  3.0801, omega:  0.1923
# theta =  3.0857, omega:  0.2670
# theta =  3.0864, omega: -0.1141
# theta =  3.0854, omega:  0.1661
# theta =  3.0857, omega: -0.2135
# theta =  3.0837, omega:  0.0003
# theta =  3.0823, omega:  0.0004
# theta =  3.0823, omega: -0.0932
# theta =  3.0814, omega: -0.0003
# theta =  3.0798, omega: -0.0012
# theta =  3.0803, omega: -0.0084
# theta =  3.0822, omega:  0.0343
# theta =  3.0846, omega:  0.0940
# theta =  3.0876, omega:  0.2242
# theta =  3.0888, omega: -0.0327
# theta =  3.0848, omega: -0.1368
# theta =  3.0809, omega: -0.1703
# theta =  3.0780, omega: -0.1966
# theta =  3.0778, omega:  0.1936
# theta =  3.0801, omega:  0.0366
# theta =  3.0833, omega: -0.0008
# theta =  3.0812, omega: -0.0408
# theta =  3.0771, omega: -0.2431
# theta =  3.0717, omega: -0.1664
# theta =  3.0697, omega: -0.0129
# theta =  3.0677, omega: -0.0000
# theta =  3.0690, omega:  0.1841
# theta =  3.0748, omega:  0.0077
# theta =  3.0766, omega:  0.0750
# theta =  3.0756, omega: -0.0020
# theta =  3.0777, omega:  0.0421
# theta =  3.0742, omega: -0.2508
# theta =  3.0729, omega:  0.1178
# theta =  3.0741, omega: -0.0154
# theta =  3.0740, omega:  0.1167
# theta =  3.0752, omega: -0.0005
# theta =  3.0747, omega:  0.0001
# theta =  3.0736, omega: -0.1033
# theta =  3.0723, omega:  0.0027
# theta =  3.0737, omega: -0.0412
# theta =  3.0677, omega: -0.2406
# theta =  3.0673, omega:  0.0989
# theta =  3.0680, omega: -0.0228
# theta =  3.0727, omega:  0.4602
# theta =  3.0780, omega: -0.0200
# theta =  3.0791, omega:  0.0004
# theta =  3.0846, omega:  0.3517
# theta =  3.0905, omega:  0.0934
# theta =  3.0907, omega: -0.0002
# theta =  3.0911, omega:  0.0001
# theta =  3.0913, omega: -0.0009
# theta =  3.0894, omega: -0.0004
# theta =  3.0884, omega:  0.0003
# theta =  3.0906, omega: -0.0086
# theta =  3.0902, omega:  0.0010
# theta =  3.0885, omega: -0.0014
# theta =  3.0898, omega: -0.0490
# theta =  3.0851, omega: -0.3252
# theta =  3.0764, omega: -0.2102
# theta =  3.0742, omega: -0.1753
# theta =  3.0718, omega: -0.0007
# theta =  3.0741, omega:  0.0226
# theta =  3.0723, omega:  0.0001
# theta =  3.0707, omega:  0.0004
# theta =  3.0710, omega:  0.0004
# theta =  3.0728, omega: -0.0003
# theta =  3.0724, omega: -0.0000
# theta =  3.0721, omega: -0.0005
# theta =  3.0712, omega: -0.1493
# theta =  3.0684, omega:  0.0139
# theta =  3.0699, omega: -0.0018
# theta =  3.0683, omega: -0.0115
# theta =  3.0675, omega: -0.0015
# theta =  3.0672, omega:  0.0008
# theta =  3.0690, omega:  0.0018
# theta =  3.0718, omega:  0.2587
# theta =  3.0749, omega: -0.0227
# theta =  3.0736, omega:  0.0005
# theta =  3.0801, omega:  0.3330
# theta =  3.0803, omega: -0.0395
# theta =  3.0779, omega: -0.1496
# theta =  3.0781, omega:  0.0057
# theta =  3.0781, omega:  0.0003
# theta =  3.0794, omega: -0.0006
# theta =  3.0782, omega: -0.0048
# theta =  3.0783, omega: -0.0268
# theta =  3.0759, omega: -0.1726
# theta =  3.0732, omega:  0.0008
# theta =  3.0764, omega:  0.2122
# theta =  3.0802, omega:  0.1104
# theta =  3.0825, omega:  0.1078
# theta =  3.0839, omega:  0.1743
# theta =  3.0879, omega: -0.1252
# theta =  3.0822, omega: -0.1936
# theta =  3.0784, omega: -0.1343
# theta =  3.0749, omega:  0.0006
# theta =  3.0723, omega: -0.2207
# theta =  3.0682, omega: -0.1533
# theta =  3.0661, omega: -0.1194
# theta =  3.0650, omega: -0.0170
# theta =  3.0652, omega:  0.0022
# theta =  3.0618, omega: -0.0006
# theta =  3.0653, omega:  0.1268
# theta =  3.0652, omega: -0.0020
# theta =  3.0663, omega: -0.1152
# theta =  3.0582, omega: -0.3862
# theta =  3.0550, omega:  0.0455
# theta =  3.0553, omega: -0.0810
# theta =  3.0531, omega:  0.0145
# theta =  3.0546, omega:  0.0014
# theta =  3.0552, omega:  0.0025
# theta =  3.0560, omega:  0.0002
# theta =  3.0524, omega: -0.0915
# theta =  3.0514, omega:  0.0816
# theta =  3.0531, omega: -0.0251
# theta =  3.0547, omega:  0.0467
# theta =  3.0556, omega:  0.0014
# theta =  3.0568, omega: -0.0004
# theta =  3.0513, omega: -0.2169
# theta =  3.0525, omega:  0.1464
# theta =  3.0609, omega:  0.4301
# theta =  3.0642, omega: -0.0571
# theta =  3.0672, omega:  0.2551
# theta =  3.0675, omega: -0.0564
# theta =  3.0670, omega: -0.0005
# theta =  3.0656, omega: -0.2055
# theta =  3.0635, omega:  0.0449
# theta =  3.0644, omega: -0.0006
# theta =  3.0649, omega: -0.0002
# theta =  3.0627, omega:  0.0006
# theta =  3.0624, omega: -0.0654
# theta =  3.0616, omega: -0.0573
# theta =  3.0620, omega:  0.0016
# theta =  3.0623, omega:  0.0001
# theta =  3.0628, omega: -0.0022
# theta =  3.0597, omega: -0.1333
# theta =  3.0613, omega:  0.0841
# theta =  3.0611, omega: -0.0007
# theta =  3.0598, omega:  0.0003
# theta =  3.0598, omega: -0.0003
# theta =  3.0604, omega:  0.0019
# theta =  3.0593, omega: -0.0500
# theta =  3.0593, omega: -0.0000
# theta =  3.0584, omega:  0.0009
# theta =  3.0606, omega:  0.0016
# theta =  3.0594, omega: -0.0027
# theta =  3.0623, omega:  0.3498
# theta =  3.0668, omega: -0.1859
# theta =  3.0602, omega: -0.1173
# theta =  3.0566, omega: -0.0815
# theta =  3.0593, omega:  0.0947
# theta =  3.0587, omega: -0.1117
# theta =  3.0585, omega:  0.0008
# theta =  3.0583, omega: -0.0000
# theta =  3.0581, omega: -0.0562
# theta =  3.0577, omega:  0.0321
# theta =  3.0581, omega:  0.0517
# theta =  3.0557, omega: -0.3006
# theta =  3.0542, omega:  0.2214
# theta =  3.0571, omega: -0.0575
# theta =  3.0537, omega: -0.0354
# theta =  3.0552, omega:  0.0744
# theta =  3.0593, omega:  0.2112
# theta =  3.0575, omega: -0.1478
# theta =  3.0591, omega:  0.0148
# theta =  3.0614, omega:  0.1193
# theta =  3.0595, omega: -0.0020
# theta =  3.0650, omega:  0.2544
# theta =  3.0646, omega: -0.1700
# theta =  3.0616, omega: -0.0333
# theta =  3.0633, omega: -0.0020
# theta =  3.0621, omega:  0.0867
# theta =  3.0619, omega: -0.0013
# theta =  3.0640, omega: -0.0440
# theta =  3.0595, omega: -0.1464
# theta =  3.0583, omega:  0.0070
# theta =  3.0588, omega:  0.0020
# theta =  3.0549, omega: -0.2418
# theta =  3.0508, omega: -0.0753
# theta =  3.0511, omega:  0.0458
# theta =  3.0535, omega:  0.0511
# theta =  3.0547, omega:  0.0004
# theta =  3.0538, omega:  0.0039
# theta =  3.0543, omega:  0.0003
# theta =  3.0531, omega:  0.0413
# theta =  3.0571, omega:  0.1650
# theta =  3.0596, omega:  0.1426
# theta =  3.0616, omega: -0.0002
# theta =  3.0660, omega:  0.2278
# theta =  3.0661, omega: -0.0536
# theta =  3.0669, omega: -0.0000
# theta =  3.0672, omega: -0.0002
# theta =  3.0665, omega: -0.0006
# theta =  3.0655, omega:  0.0126
# theta =  3.0639, omega: -0.0007
# theta =  3.0676, omega: -0.0001
# theta =  3.0672, omega:  0.2101
# theta =  3.0718, omega: -0.0165
# theta =  3.0727, omega:  0.0006
# theta =  3.0700, omega: -0.0479
# theta =  3.0670, omega: -0.2149
# theta =  3.0634, omega: -0.0636
# theta =  3.0637, omega:  0.0014
# theta =  3.0642, omega: -0.0013
# theta =  3.0607, omega: -0.0011
# theta =  3.0644, omega:  0.0228
# theta =  3.0626, omega: -0.0596
# theta =  3.0612, omega:  0.0406
# theta =  3.0617, omega: -0.2720
# theta =  3.0563, omega: -0.0892
# theta =  3.0532, omega: -0.1077
# theta =  3.0539, omega:  0.2235
# theta =  3.0552, omega: -0.0924
# theta =  3.0609, omega:  0.3777
# theta =  3.0595, omega: -0.1011
# theta =  3.0615, omega:  0.0007
# theta =  3.0608, omega: -0.0009
# theta =  3.0615, omega:  0.0029
# theta =  3.0618, omega: -0.0013
# theta =  3.0629, omega:  0.0025
# theta =  3.0672, omega:  0.2829
# theta =  3.0762, omega:  0.5057
# theta =  3.0763, omega: -0.2740
# theta =  3.0749, omega:  0.1269
# theta =  3.0757, omega: -0.1931
# theta =  3.0728, omega: -0.0908
# theta =  3.0722, omega:  0.0022
# theta =  3.0690, omega: -0.0025
# theta =  3.0694, omega: -0.0813
# theta =  3.0690, omega: -0.0153
# theta =  3.0700, omega:  0.0001
# theta =  3.0692, omega:  0.0643
# theta =  3.0689, omega: -0.0021
# theta =  3.0693, omega:  0.0014
# theta =  3.0684, omega:  0.0090
# theta =  3.0703, omega: -0.0012
# theta =  3.0719, omega:  0.0756
# theta =  3.0720, omega: -0.0042
# theta =  3.0692, omega: -0.0005
# theta =  3.0715, omega: -0.0015
# theta =  3.0702, omega: -0.0525
# theta =  3.0738, omega:  0.2738
# theta =  3.0779, omega:  0.0379
# theta =  3.0800, omega:  0.2430
# theta =  3.0798, omega: -0.1780
# theta =  3.0799, omega:  0.0017
# theta =  3.0803, omega: -0.0008
# theta =  3.0782, omega: -0.0010
# theta =  3.0782, omega: -0.0024
# theta =  3.0797, omega:  0.0012
# theta =  3.0793, omega: -0.0434
# theta =  3.0784, omega:  0.0001
# theta =  3.0772, omega: -0.0200
# theta =  3.0807, omega:  0.0936
# theta =  3.0772, omega: -0.1725
# theta =  3.0764, omega:  0.0296
# theta =  3.0737, omega: -0.2111
# theta =  3.0715, omega: -0.0018
# theta =  3.0708, omega: -0.0610
# theta =  3.0721, omega:  0.0832
# theta =  3.0751, omega:  0.2713
# theta =  3.0797, omega: -0.0069
# theta =  3.0810, omega:  0.2111
# theta =  3.0808, omega: -0.1864
# theta =  3.0779, omega: -0.0848
# theta =  3.0761, omega: -0.0015
# theta =  3.0753, omega: -0.0000
# theta =  3.0764, omega:  0.0934
# theta =  3.0748, omega: -0.2195
# theta =  3.0733, omega:  0.0137
# theta =  3.0734, omega: -0.0896
# theta =  3.0730, omega:  0.0003
# theta =  3.0733, omega:  0.1044
# theta =  3.0728, omega: -0.0010
# theta =  3.0722, omega:  0.0027
# theta =  3.0693, omega: -0.2003
# theta =  3.0690, omega: -0.0916
# theta =  3.0703, omega:  0.2238
# theta =  3.0712, omega: -0.0602
# theta =  3.0714, omega: -0.0021
# theta =  3.0703, omega: -0.0005
# theta =  3.0735, omega:  0.2295
# theta =  3.0780, omega:  0.0676
# theta =  3.0763, omega: -0.0005
# theta =  3.0786, omega:  0.0554
# theta =  3.0782, omega: -0.0028
# theta =  3.0779, omega: -0.0001
# theta =  3.0791, omega:  0.0747
# theta =  3.0826, omega:  0.1634
# theta =  3.0798, omega: -0.2343
# theta =  3.0774, omega: -0.0960
# theta =  3.0749, omega:  0.0008
# theta =  3.0749, omega:  0.0004
# theta =  3.0728, omega: -0.2397
# theta =  3.0699, omega:  0.0013
# theta =  3.0720, omega:  0.2005
# theta =  3.0741, omega: -0.0261
# theta =  3.0740, omega:  0.0596
# theta =  3.0735, omega: -0.0017
# theta =  3.0752, omega:  0.0832
# theta =  3.0747, omega: -0.0617
# theta =  3.0756, omega:  0.0118
# theta =  3.0745, omega: -0.0010
# theta =  3.0748, omega: -0.0012
# theta =  3.0770, omega: -0.0009
# theta =  3.0762, omega:  0.0008
# theta =  3.0767, omega:  0.0245
# theta =  3.0787, omega:  0.1340
# theta =  3.0848, omega:  0.3978
# theta =  3.0855, omega: -0.1060
# theta =  3.0849, omega: -0.1045
# theta =  3.0870, omega:  0.1222
# theta =  3.0878, omega:  0.1794
# theta =  3.0910, omega:  0.0521
# theta =  3.0887, omega: -0.2926
# theta =  3.0835, omega: -0.1337
# theta =  3.0804, omega:  0.0012
# theta =  3.0804, omega: -0.1390
# theta =  3.0801, omega:  0.0096
# theta =  3.0802, omega: -0.0401
# theta =  3.0769, omega: -0.2409
# theta =  3.0717, omega: -0.0362
# theta =  3.0713, omega:  0.0006
# theta =  3.0716, omega: -0.1027
# theta =  3.0693, omega: -0.0103
# theta =  3.0695, omega:  0.0006
# theta =  3.0679, omega: -0.1787
# theta =  3.0646, omega: -0.0729
# theta =  3.0649, omega:  0.0005
# theta =  3.0655, omega: -0.0013
# theta =  3.0642, omega: -0.0023
# theta =  3.0597, omega: -0.1067
# theta =  3.0601, omega: -0.0824
# theta =  3.0590, omega:  0.0030
# theta =  3.0624, omega:  0.1631
# theta =  3.0650, omega:  0.1152
# theta =  3.0661, omega: -0.0010
# theta =  3.0656, omega: -0.0478
# theta =  3.0675, omega:  0.0991
# theta =  3.0687, omega: -0.0149
# theta =  3.0670, omega: -0.0445
# theta =  3.0660, omega:  0.0027
# theta =  3.0648, omega: -0.0021
# theta =  3.0661, omega: -0.0004
# theta =  3.0694, omega:  0.1913
# theta =  3.0710, omega: -0.0108
# theta =  3.0679, omega: -0.1507
# theta =  3.0659, omega:  0.0013
# theta =  3.0657, omega: -0.0001
# theta =  3.0663, omega:  0.1162
# theta =  3.0694, omega:  0.0001
# theta =  3.0685, omega: -0.1324
# theta =  3.0665, omega:  0.0423
# theta =  3.0668, omega: -0.0020
# theta =  3.0665, omega:  0.0011
# theta =  3.0685, omega: -0.1383
# theta =  3.0650, omega:  0.0002
# theta =  3.0643, omega:  0.0016
# theta =  3.0674, omega:  0.0187
# theta =  3.0651, omega: -0.0006
# theta =  3.0653, omega:  0.0009
# theta =  3.0637, omega: -0.0006
# theta =  3.0671, omega:  0.0003
# theta =  3.0659, omega: -0.0008
# theta =  3.0652, omega: -0.0004
# theta =  3.0653, omega:  0.0003
# theta =  3.0663, omega:  0.1278
# theta =  3.0695, omega:  0.1484
# theta =  3.0689, omega: -0.0636
# theta =  3.0696, omega:  0.0011
# theta =  3.0759, omega:  0.4476
# theta =  3.0796, omega: -0.1345
# theta =  3.0778, omega:  0.0273
# theta =  3.0742, omega: -0.2594
# theta =  3.0717, omega: -0.0464
# theta =  3.0728, omega: -0.0004
# theta =  3.0717, omega: -0.0012
# theta =  3.0725, omega:  0.0721
# theta =  3.0702, omega: -0.0858
# theta =  3.0709, omega:  0.0001
# theta =  3.0686, omega: -0.1294
# theta =  3.0656, omega: -0.1035
# theta =  3.0661, omega:  0.0009
# theta =  3.0653, omega: -0.0615
# theta =  3.0673, omega:  0.2323
# theta =  3.0707, omega: -0.0023
# theta =  3.0674, omega: -0.1933
# theta =  3.0606, omega: -0.1998
# theta =  3.0578, omega: -0.1846
# theta =  3.0603, omega:  0.2569
# theta =  3.0592, omega: -0.0997
# theta =  3.0611, omega: -0.0010
# theta =  3.0580, omega:  0.0018
# theta =  3.0596, omega:  0.0014
# theta =  3.0622, omega:  0.2999
# theta =  3.0672, omega: -0.0473
# theta =  3.0674, omega:  0.0375
# theta =  3.0626, omega: -0.1640
# theta =  3.0655, omega:  0.2131
# theta =  3.0682, omega: -0.0279
# theta =  3.0658, omega: -0.0005
# theta =  3.0686, omega:  0.1170
# theta =  3.0689, omega:  0.0007
# theta =  3.0703, omega:  0.0009
# theta =  3.0698, omega: -0.0020
# theta =  3.0675, omega: -0.0299
# theta =  3.0711, omega:  0.1367
# theta =  3.0725, omega: -0.0116
# theta =  3.0700, omega: -0.0008
# theta =  3.0688, omega: -0.2115
# theta =  3.0663, omega: -0.0190
# theta =  3.0657, omega: -0.1249
# theta =  3.0664, omega:  0.3267
# theta =  3.0729, omega:  0.1173
# theta =  3.0707, omega: -0.1277
# theta =  3.0669, omega: -0.2143
# theta =  3.0624, omega: -0.2117
# theta =  3.0623, omega:  0.0742
# theta =  3.0603, omega: -0.0008
# theta =  3.0606, omega: -0.0016
# theta =  3.0611, omega:  0.0011
# theta =  3.0632, omega:  0.0017
# theta =  3.0595, omega: -0.2048
# theta =  3.0575, omega:  0.0005
# theta =  3.0565, omega: -0.0008
# theta =  3.0606, omega:  0.2458
# theta =  3.0610, omega: -0.0953
# theta =  3.0568, omega: -0.2704
# theta =  3.0530, omega: -0.1248
# theta =  3.0500, omega:  0.0005
# theta =  3.0513, omega:  0.0339
# theta =  3.0508, omega:  0.0021
# theta =  3.0523, omega:  0.0008
# theta =  3.0523, omega: -0.0008
# theta =  3.0516, omega:  0.0019
# theta =  3.0519, omega:  0.1168
# theta =  3.0542, omega:  0.0232
# theta =  3.0569, omega:  0.0932
# theta =  3.0580, omega: -0.0001
# theta =  3.0553, omega: -0.1324
# theta =  3.0506, omega: -0.1690
# theta =  3.0502, omega:  0.0032
# theta =  3.0492, omega: -0.0006
# theta =  3.0510, omega:  0.1446
# theta =  3.0561, omega:  0.1279
# theta =  3.0598, omega:  0.2424
# theta =  3.0648, omega:  0.1061
# theta =  3.0646, omega: -0.0005
# theta =  3.0666, omega: -0.0017
# theta =  3.0641, omega: -0.0672
# theta =  3.0653, omega:  0.0005
# theta =  3.0628, omega:  0.0003
# theta =  3.0616, omega:  0.0265
# theta =  3.0685, omega:  0.1360
# theta =  3.0698, omega: -0.0002
# theta =  3.0654, omega: -0.0605
# theta =  3.0666, omega:  0.0014
# theta =  3.0650, omega:  0.0013
# theta =  3.0661, omega:  0.0001
# theta =  3.0686, omega: -0.0009
# theta =  3.0670, omega: -0.0002
# theta =  3.0665, omega: -0.0376
# theta =  3.0655, omega:  0.0002
# theta =  3.0672, omega:  0.1314
# theta =  3.0672, omega: -0.0190
# theta =  3.0671, omega:  0.0477
# theta =  3.0687, omega:  0.1562
# theta =  3.0694, omega: -0.1108
# theta =  3.0709, omega:  0.1683
# theta =  3.0730, omega:  0.0489
# theta =  3.0768, omega:  0.1875
# theta =  3.0798, omega: -0.0947
# theta =  3.0737, omega: -0.2515
# theta =  3.0688, omega: -0.0990
# theta =  3.0688, omega:  0.0014
# theta =  3.0646, omega: -0.2849
# theta =  3.0623, omega:  0.1181
# theta =  3.0646, omega: -0.0018
# theta =  3.0656, omega:  0.0012
# theta =  3.0648, omega: -0.1431
# theta =  3.0637, omega:  0.1918
# theta =  3.0626, omega: -0.2546
# theta =  3.0581, omega:  0.0010
# theta =  3.0595, omega: -0.0011
# theta =  3.0599, omega:  0.0011
# theta =  3.0617, omega:  0.0987
# theta =  3.0619, omega: -0.0007
# theta =  3.0615, omega: -0.0002
# theta =  3.0617, omega:  0.0299
# theta =  3.0653, omega:  0.1146
# theta =  3.0670, omega:  0.1353
# theta =  3.0683, omega: -0.0588
# theta =  3.0687, omega:  0.1192
# theta =  3.0692, omega:  0.0001
# theta =  3.0657, omega: -0.2466
# theta =  3.0675, omega:  0.2278
# theta =  3.0686, omega: -0.0089
# theta =  3.0692, omega: -0.0000
# theta =  3.0690, omega:  0.0012
# theta =  3.0704, omega:  0.0748
# theta =  3.0680, omega:  0.0003
# theta =  3.0700, omega: -0.0010
# theta =  3.0710, omega:  0.0012
# theta =  3.0707, omega: -0.0029
# theta =  3.0709, omega:  0.0683
# theta =  3.0714, omega: -0.0014
# theta =  3.0703, omega: -0.0021
# theta =  3.0707, omega: -0.0021
# theta =  3.0672, omega: -0.1976
# theta =  3.0626, omega: -0.1459
# theta =  3.0651, omega:  0.1620
# theta =  3.0657, omega: -0.0078
# theta =  3.0654, omega:  0.0007
# theta =  3.0684, omega:  0.1640
# theta =  3.0697, omega: -0.0017
# theta =  3.0693, omega: -0.0001
# theta =  3.0710, omega:  0.0010
# theta =  3.0696, omega:  0.0012
# theta =  3.0710, omega:  0.0007
# theta =  3.0713, omega: -0.0002
# theta =  3.0708, omega: -0.0011
# theta =  3.0730, omega:  0.1715
# theta =  3.0700, omega: -0.3087
# theta =  3.0639, omega: -0.1310
# theta =  3.0644, omega:  0.0007
# theta =  3.0645, omega:  0.0017
# theta =  3.0629, omega:  0.0009
# theta =  3.0667, omega:  0.1825
# theta =  3.0656, omega: -0.0575
# theta =  3.0644, omega:  0.0025
# theta =  3.0643, omega: -0.0001
# theta =  3.0681, omega: -0.0023
# theta =  3.0665, omega: -0.0008
# theta =  3.0648, omega: -0.1341
# theta =  3.0630, omega:  0.0072
# theta =  3.0630, omega:  0.0001
# theta =  3.0680, omega:  0.0970
# theta =  3.0677, omega:  0.0128
# theta =  3.0664, omega: -0.0337
# theta =  3.0645, omega: -0.0018
# theta =  3.0653, omega:  0.0751
# theta =  3.0715, omega:  0.3401
# theta =  3.0767, omega:  0.0174
# theta =  3.0765, omega: -0.0017
# theta =  3.0749, omega: -0.1335
# theta =  3.0764, omega:  0.0351
# theta =  3.0739, omega:  0.0011
# theta =  3.0720, omega: -0.2573
# theta =  3.0633, omega: -0.3321
# theta =  3.0607, omega:  0.0914
# theta =  3.0616, omega: -0.0089
# theta =  3.0592, omega:  0.0005
# theta =  3.0619, omega: -0.0004
# theta =  3.0627, omega: -0.0012
# theta =  3.0617, omega:  0.0005
# theta =  3.0606, omega: -0.1519
# theta =  3.0590, omega: -0.0316
# theta =  3.0572, omega: -0.0145
# theta =  3.0564, omega:  0.0018
# theta =  3.0568, omega: -0.0425
# theta =  3.0574, omega:  0.0006
# theta =  3.0566, omega:  0.0015
# theta =  3.0563, omega:  0.0000
# theta =  3.0537, omega:  0.0008
# theta =  3.0563, omega: -0.0030
# theta =  3.0579, omega: -0.0005
# theta =  3.0559, omega: -0.0010
# theta =  3.0561, omega:  0.0006
# theta =  3.0559, omega:  0.0032
# theta =  3.0583, omega:  0.1204
# theta =  3.0603, omega: -0.0042
# theta =  3.0591, omega: -0.0000
# theta =  3.0609, omega:  0.0651
# theta =  3.0618, omega:  0.0442
# theta =  3.0604, omega:  0.0005
# theta =  3.0608, omega:  0.0384
# theta =  3.0612, omega: -0.0450
# theta =  3.0594, omega:  0.0014
# theta =  3.0620, omega:  0.0002
# theta =  3.0571, omega: -0.2412
# theta =  3.0540, omega: -0.1875
# theta =  3.0512, omega:  0.0277
# theta =  3.0505, omega: -0.2861
# theta =  3.0493, omega:  0.3481
# theta =  3.0525, omega: -0.0053
# theta =  3.0527, omega: -0.0008
# theta =  3.0517, omega:  0.0727
# theta =  3.0539, omega:  0.0013
# theta =  3.0545, omega:  0.0654
# theta =  3.0587, omega:  0.1333
# theta =  3.0593, omega: -0.0225
# theta =  3.0594, omega:  0.0007
# theta =  3.0598, omega: -0.0004
# theta =  3.0600, omega: -0.0012
# theta =  3.0564, omega:  0.0011
# theta =  3.0581, omega:  0.0009
# theta =  3.0610, omega:  0.2872
# theta =  3.0647, omega: -0.0027
# theta =  3.0659, omega:  0.1250
# theta =  3.0663, omega: -0.0907
# theta =  3.0644, omega:  0.0022
# theta =  3.0696, omega:  0.1432
# theta =  3.0695, omega:  0.0036
# theta =  3.0720, omega: -0.0001
# theta =  3.0691, omega:  0.0020
# theta =  3.0718, omega:  0.1592
# theta =  3.0742, omega:  0.0729
# theta =  3.0755, omega: -0.0002
# theta =  3.0746, omega: -0.0838
# theta =  3.0696, omega: -0.1987
# theta =  3.0687, omega: -0.0271
# theta =  3.0682, omega:  0.0537
# theta =  3.0685, omega: -0.0329
# theta =  3.0687, omega:  0.0013
# theta =  3.0678, omega:  0.0458
# theta =  3.0667, omega: -0.1265
# theta =  3.0682, omega: -0.0016
# theta =  3.0664, omega: -0.0006
# theta =  3.0648, omega:  0.0017
# theta =  3.0640, omega: -0.1524
# theta =  3.0643, omega:  0.0011
# theta =  3.0624, omega:  0.0018
# theta =  3.0629, omega:  0.0002
# theta =  3.0612, omega: -0.0544
# theta =  3.0591, omega: -0.0192
# theta =  3.0605, omega:  0.0010
# theta =  3.0608, omega:  0.0127
# theta =  3.0597, omega:  0.0026
# theta =  3.0621, omega: -0.0177
# theta =  3.0603, omega:  0.0001
# theta =  3.0613, omega:  0.0003
# theta =  3.0612, omega: -0.0236
# theta =  3.0609, omega: -0.0025
# theta =  3.0616, omega:  0.0006
# theta =  3.0594, omega: -0.0008
# theta =  3.0584, omega:  0.0007
# theta =  3.0624, omega:  0.1639
# theta =  3.0608, omega: -0.1498
# theta =  3.0607, omega:  0.0701
# theta =  3.0662, omega:  0.3786
# theta =  3.0722, omega: -0.0055
# theta =  3.0690, omega: -0.0765
# theta =  3.0705, omega:  0.0008
# theta =  3.0699, omega:  0.0059
# theta =  3.0692, omega: -0.0013
# theta =  3.0716, omega:  0.0002
# theta =  3.0694, omega:  0.0014
# theta =  3.0683, omega: -0.0528
# theta =  3.0692, omega:  0.0012
# theta =  3.0735, omega:  0.2484
# theta =  3.0745, omega: -0.0821
# theta =  3.0712, omega: -0.2577
# theta =  3.0648, omega: -0.0829
# theta =  3.0636, omega: -0.0634
# theta =  3.0635, omega: -0.0000
# theta =  3.0629, omega: -0.0009
# theta =  3.0622, omega: -0.0014
# theta =  3.0636, omega:  0.0479
# theta =  3.0639, omega: -0.1446
# theta =  3.0607, omega:  0.0421
# theta =  3.0611, omega:  0.0007
# theta =  3.0624, omega: -0.0007
# theta =  3.0628, omega:  0.1134
# theta =  3.0635, omega: -0.0200
# theta =  3.0631, omega: -0.0004
# theta =  3.0660, omega:  0.1301
# theta =  3.0676, omega:  0.1368
# theta =  3.0718, omega:  0.0013
# theta =  3.0707, omega:  0.0071
# theta =  3.0728, omega: -0.0007
# theta =  3.0708, omega: -0.0002
# theta =  3.0706, omega: -0.0178
# theta =  3.0732, omega:  0.2383
# theta =  3.0710, omega: -0.4084
# theta =  3.0666, omega:  0.0179
# theta =  3.0653, omega:  0.0004
# theta =  3.0668, omega: -0.0001
# theta =  3.0652, omega: -0.0011
# theta =  3.0675, omega:  0.0264
# theta =  3.0630, omega: -0.1917
# theta =  3.0625, omega:  0.0925
# theta =  3.0644, omega: -0.0338
# theta =  3.0676, omega:  0.4268
# theta =  3.0769, omega:  0.1989
# theta =  3.0802, omega:  0.1066
# theta =  3.0781, omega: -0.2928
# theta =  3.0758, omega:  0.0069
# theta =  3.0779, omega:  0.1349
# theta =  3.0751, omega: -0.2287
# theta =  3.0708, omega: -0.1586
# theta =  3.0689, omega:  0.1398
# theta =  3.0719, omega: -0.0375
# theta =  3.0695, omega:  0.0005
# theta =  3.0706, omega:  0.0021
# theta =  3.0676, omega: -0.1863
# theta =  3.0663, omega:  0.0057
# theta =  3.0685, omega:  0.0019
# theta =  3.0639, omega: -0.1623
# theta =  3.0643, omega:  0.1453
# theta =  3.0670, omega: -0.0012
# theta =  3.0654, omega: -0.1955
# theta =  3.0624, omega:  0.0407
# theta =  3.0653, omega:  0.2211
# theta =  3.0670, omega: -0.0030
# theta =  3.0691, omega:  0.0014
# theta =  3.0682, omega:  0.0025
# theta =  3.0681, omega: -0.0000
# theta =  3.0696, omega:  0.0021
# theta =  3.0697, omega: -0.0018
# theta =  3.0702, omega:  0.1011
# theta =  3.0682, omega: -0.0374
# theta =  3.0700, omega: -0.0003
# theta =  3.0699, omega: -0.0131
# theta =  3.0681, omega: -0.0002
# theta =  3.0715, omega:  0.1558
# theta =  3.0694, omega: -0.0031
# theta =  3.0725, omega: -0.0008
# theta =  3.0736, omega:  0.0229
# theta =  3.0717, omega: -0.1381
# theta =  3.0716, omega:  0.0015
# theta =  3.0692, omega: -0.0204
# theta =  3.0693, omega:  0.0028
# theta =  3.0697, omega:  0.0013
# theta =  3.0704, omega:  0.0002
# theta =  3.0700, omega:  0.0015
# theta =  3.0710, omega:  0.0008
# theta =  3.0689, omega: -0.0100
# theta =  3.0688, omega:  0.0001
# theta =  3.0705, omega:  0.0568
# theta =  3.0722, omega:  0.0877
# theta =  3.0730, omega:  0.0006
# theta =  3.0730, omega: -0.0008
# theta =  3.0748, omega:  0.1105
# theta =  3.0752, omega: -0.0024
# theta =  3.0767, omega: -0.0006
# theta =  3.0721, omega: -0.1749
# theta =  3.0724, omega:  0.1198
# ...
# theta =  3.0822, omega:  0.0790
# theta =  3.0808, omega: -0.0213
# theta =  3.0853, omega:  0.2409
# theta =  3.0861, omega: -0.0214
# theta =  3.0878, omega: -0.0014
# theta =  3.0860, omega:  0.0001
# theta =  3.0868, omega: -0.0065
# theta =  3.0851, omega: -0.0294
# theta =  3.0880, omega:  0.0009
# theta =  3.0853, omega:  0.0002
# theta =  3.0830, omega: -0.2462
# theta =  3.0805, omega:  0.0023
# theta =  3.0792, omega: -0.0003
# theta =  3.0790, omega:  0.0006
# theta =  3.0811, omega:  0.0231
# theta =  3.0790, omega: -0.0013
# theta =  3.0807, omega: -0.1044
# theta =  3.0799, omega: -0.0003
# theta =  3.0787, omega: -0.0018
# theta =  3.0804, omega:  0.0001
# theta =  3.0766, omega: -0.1210
# theta =  3.0752, omega: -0.0453
# theta =  3.0718, omega: -0.2344
# theta =  3.0688, omega:  0.0010
# theta =  3.0727, omega:  0.2611
# theta =  3.0744, omega: -0.0153
# theta =  3.0755, omega:  0.0000
# theta =  3.0742, omega: -0.0024
# theta =  3.0729, omega: -0.0016
# theta =  3.0737, omega: -0.0004
# theta =  3.0747, omega:  0.0742
# theta =  3.0757, omega: -0.0015
# theta =  3.0751, omega:  0.0007
# theta =  3.0745, omega: -0.0272
# theta =  3.0747, omega: -0.0120
# theta =  3.0754, omega:  0.0670
# theta =  3.0761, omega: -0.0006
# theta =  3.0773, omega:  0.0002
# theta =  3.0755, omega:  0.0003
# theta =  3.0763, omega: -0.0004
# theta =  3.0755, omega: -0.0449
# theta =  3.0719, omega: -0.2424
# theta =  3.0668, omega: -0.2768
# theta =  3.0651, omega:  0.0633
# theta =  3.0638, omega:  0.0051
# theta =  3.0632, omega: -0.0350
# theta =  3.0650, omega:  0.0951
# theta =  3.0652, omega: -0.0192
# theta =  3.0649, omega:  0.0013
# theta =  3.0661, omega:  0.1632
# theta =  3.0660, omega: -0.1841
# theta =  3.0696, omega:  0.4051
# theta =  3.0739, omega: -0.1188
# theta =  3.0729, omega:  0.0019
# theta =  3.0708, omega: -0.0019
# theta =  3.0732, omega:  0.0009
# theta =  3.0732, omega:  0.1225
# theta =  3.0742, omega:  0.0005
# theta =  3.0721, omega: -0.0001
# theta =  3.0730, omega: -0.0756
# theta =  3.0707, omega: -0.0006
# theta =  3.0692, omega: -0.0512
# theta =  3.0693, omega: -0.0938
# theta =  3.0708, omega:  0.0865
# theta =  3.0716, omega:  0.0622
# theta =  3.0715, omega: -0.0012
# theta =  3.0720, omega: -0.0005
# theta =  3.0759, omega:  0.1370
# theta =  3.0766, omega: -0.0008
# theta =  3.0734, omega: -0.0442
# theta =  3.0755, omega:  0.0770
# theta =  3.0762, omega:  0.0001
# theta =  3.0772, omega:  0.0525
# theta =  3.0747, omega: -0.0110
# theta =  3.0780, omega: -0.0006
# theta =  3.0761, omega: -0.0012
# theta =  3.0768, omega:  0.0002
# theta =  3.0767, omega:  0.0073
# theta =  3.0772, omega:  0.0013
# theta =  3.0765, omega: -0.0006
# theta =  3.0775, omega: -0.0008
# theta =  3.0750, omega: -0.0023
# theta =  3.0772, omega:  0.0010
# theta =  3.0780, omega:  0.0006
# theta =  3.0756, omega: -0.0001
# theta =  3.0758, omega: -0.0031
# theta =  3.0759, omega: -0.0011
# theta =  3.0754, omega: -0.1177
# theta =  3.0728, omega: -0.0511
# theta =  3.0736, omega: -0.0010
# theta =  3.0756, omega:  0.2206
# theta =  3.0762, omega: -0.0959
# theta =  3.0757, omega:  0.0020
# theta =  3.0785, omega:  0.1524
# theta =  3.0801, omega:  0.0457
# theta =  3.0815, omega:  0.0005
# theta =  3.0802, omega: -0.0012
# theta =  3.0800, omega:  0.0028
# theta =  3.0787, omega: -0.1368
# theta =  3.0770, omega:  0.0713
# theta =  3.0776, omega: -0.0008
# theta =  3.0756, omega: -0.1918
# theta =  3.0740, omega: -0.0600
# theta =  3.0701, omega:  0.0017
# theta =  3.0710, omega: -0.2020
# theta =  3.0681, omega: -0.0865
# theta =  3.0667, omega:  0.0026
# theta =  3.0627, omega: -0.2221
# theta =  3.0583, omega: -0.2206
# theta =  3.0538, omega:  0.0011
# theta =  3.0541, omega:  0.0013
# theta =  3.0576, omega:  0.0558
# theta =  3.0514, omega: -0.4318
# theta =  3.0434, omega: -0.0683
# theta =  3.0458, omega:  0.0758
# theta =  3.0480, omega:  0.0679
# theta =  3.0458, omega: -0.0425
# theta =  3.0496, omega:  0.1461
# theta =  3.0506, omega: -0.0002
# theta =  3.0505, omega:  0.0015
# theta =  3.0524, omega: -0.0000
# theta =  3.0512, omega:  0.1463
# theta =  3.0538, omega:  0.0016
# theta =  3.0529, omega: -0.0025
# theta =  3.0541, omega: -0.0003
# theta =  3.0560, omega:  0.0833
# theta =  3.0531, omega: -0.1319
# theta =  3.0520, omega:  0.0098
# theta =  3.0518, omega:  0.0013
# theta =  3.0534, omega:  0.0127
# theta =  3.0552, omega:  0.1014
# theta =  3.0538, omega: -0.0056
# theta =  3.0543, omega:  0.0031
# theta =  3.0599, omega:  0.3254
# theta =  3.0621, omega: -0.0387
# theta =  3.0612, omega:  0.0003
# theta =  3.0605, omega: -0.0002
# theta =  3.0609, omega:  0.0020
# theta =  3.0608, omega: -0.0901
# theta =  3.0644, omega:  0.2776
# theta =  3.0661, omega:  0.0779
# theta =  3.0687, omega: -0.0007
# theta =  3.0684, omega:  0.1211
# theta =  3.0747, omega:  0.3530
# theta =  3.0796, omega: -0.0876
# theta =  3.0753, omega: -0.0005
# theta =  3.0782, omega: -0.0001
# theta =  3.0771, omega: -0.0008
# theta =  3.0772, omega:  0.0007
# theta =  3.0754, omega: -0.1887
# theta =  3.0697, omega: -0.3408
# theta =  3.0646, omega:  0.0433
# theta =  3.0645, omega:  0.0011
# theta =  3.0642, omega:  0.1201
# theta =  3.0668, omega: -0.0234
# theta =  3.0676, omega: -0.0363
# theta =  3.0685, omega:  0.1354
# theta =  3.0705, omega:  0.0662
# theta =  3.0718, omega:  0.0188
# theta =  3.0736, omega: -0.0491
# theta =  3.0698, omega:  0.0010
# theta =  3.0713, omega: -0.0018
# theta =  3.0690, omega: -0.0867
# theta =  3.0657, omega: -0.0713
# theta =  3.0655, omega: -0.1975
# theta =  3.0645, omega:  0.0523
# theta =  3.0660, omega:  0.1195
# theta =  3.0716, omega:  0.3272
# theta =  3.0768, omega: -0.0128
# theta =  3.0695, omega: -0.2961
# theta =  3.0712, omega:  0.0338
# theta =  3.0695, omega: -0.0132
# theta =  3.0692, omega: -0.0028
# theta =  3.0667, omega: -0.0347
# theta =  3.0666, omega: -0.0882
# theta =  3.0671, omega:  0.0021
# theta =  3.0651, omega: -0.0014
# theta =  3.0671, omega:  0.0006
# theta =  3.0679, omega:  0.2086
# theta =  3.0730, omega:  0.1344
# theta =  3.0727, omega: -0.1118
# theta =  3.0719, omega:  0.0705
# theta =  3.0731, omega:  0.0017
# theta =  3.0726, omega: -0.1642
# theta =  3.0690, omega:  0.0015
# theta =  3.0697, omega: -0.1199
# theta =  3.0632, omega: -0.1760
# theta =  3.0609, omega: -0.0139
# theta =  3.0606, omega:  0.0007
# theta =  3.0608, omega:  0.0022
# theta =  3.0607, omega: -0.0002
# theta =  3.0621, omega:  0.0008
# theta =  3.0630, omega:  0.1330
# theta =  3.0730, omega:  0.5248
# theta =  3.0845, omega:  0.5230
# theta =  3.0877, omega: -0.2970
# theta =  3.0807, omega: -0.0457
# theta =  3.0821, omega: -0.0009
# theta =  3.0833, omega:  0.0346
# theta =  3.0812, omega: -0.2387
# theta =  3.0779, omega: -0.0323
# theta =  3.0749, omega: -0.1885
# theta =  3.0714, omega:  0.0057
# theta =  3.0714, omega:  0.0005
# theta =  3.0703, omega: -0.0014
# theta =  3.0728, omega: -0.0190
# theta =  3.0690, omega: -0.1208
# theta =  3.0700, omega:  0.0008
# theta =  3.0684, omega:  0.0008
# theta =  3.0677, omega:  0.0007
# theta =  3.0717, omega: -0.0011
# theta =  3.0720, omega:  0.1166
# theta =  3.0753, omega:  0.1559
# theta =  3.0738, omega: -0.0961
# theta =  3.0766, omega:  0.1232
# theta =  3.0758, omega: -0.0040
# theta =  3.0771, omega: -0.0025
# theta =  3.0751, omega: -0.0447
# theta =  3.0743, omega: -0.0034
# theta =  3.0730, omega: -0.1128
# theta =  3.0721, omega: -0.0001
# theta =  3.0713, omega: -0.0037
# theta =  3.0711, omega: -0.0882
# theta =  3.0726, omega:  0.1277
# theta =  3.0723, omega: -0.0003
# theta =  3.0731, omega: -0.0017
# theta =  3.0731, omega: -0.0401
# theta =  3.0732, omega: -0.0004
# theta =  3.0719, omega:  0.0003
# theta =  3.0712, omega: -0.1758
# theta =  3.0696, omega:  0.0005
# theta =  3.0690, omega:  0.0007
# theta =  3.0695, omega:  0.0003
# theta =  3.0684, omega:  0.0003
# theta =  3.0664, omega: -0.1671
# theta =  3.0666, omega:  0.0824
# theta =  3.0710, omega:  0.2015
# theta =  3.0717, omega: -0.0013
# theta =  3.0722, omega:  0.0298
# theta =  3.0686, omega: -0.1307
# theta =  3.0678, omega: -0.0134
# theta =  3.0690, omega: -0.0012
# theta =  3.0714, omega:  0.0011
# theta =  3.0684, omega:  0.0000
# theta =  3.0687, omega:  0.0011
# theta =  3.0695, omega:  0.0189
# theta =  3.0698, omega: -0.0014
# theta =  3.0691, omega: -0.0369
# theta =  3.0692, omega:  0.0844
# theta =  3.0660, omega: -0.1783
# theta =  3.0680, omega:  0.0578
# theta =  3.0721, omega:  0.1384
# theta =  3.0713, omega: -0.0268
# theta =  3.0708, omega: -0.0637
# theta =  3.0677, omega:  0.0012
# theta =  3.0659, omega: -0.0828
# theta =  3.0685, omega:  0.0520
# theta =  3.0693, omega: -0.0019
# theta =  3.0665, omega:  0.0076
# theta =  3.0688, omega: -0.0002
# theta =  3.0688, omega:  0.0005
# theta =  3.0715, omega: -0.0006
# theta =  3.0684, omega:  0.0634
# theta =  3.0692, omega: -0.0002
# theta =  3.0696, omega:  0.0007
# theta =  3.0682, omega: -0.0705
# theta =  3.0682, omega:  0.0009
# theta =  3.0649, omega: -0.2902
# theta =  3.0639, omega:  0.2073
# theta =  3.0659, omega: -0.0035
# theta =  3.0674, omega: -0.0018
# theta =  3.0659, omega: -0.0002
# theta =  3.0664, omega: -0.0004
# theta =  3.0643, omega: -0.2875
# theta =  3.0608, omega:  0.0995
# theta =  3.0611, omega: -0.1086
# theta =  3.0616, omega:  0.0630
# theta =  3.0598, omega: -0.0364
# theta =  3.0602, omega:  0.0013
# theta =  3.0605, omega:  0.0004
# theta =  3.0596, omega:  0.0049
# theta =  3.0604, omega:  0.0031
# theta =  3.0609, omega: -0.0175
# theta =  3.0604, omega:  0.0011
# theta =  3.0588, omega:  0.0368
# theta =  3.0596, omega: -0.1285
# theta =  3.0579, omega: -0.0271
# theta =  3.0560, omega: -0.0898
# theta =  3.0582, omega:  0.2234
# theta =  3.0588, omega: -0.0518
# theta =  3.0586, omega:  0.0004
# theta =  3.0615, omega:  0.0966
# theta =  3.0575, omega: -0.1918
# theta =  3.0582, omega:  0.0157
# theta =  3.0582, omega:  0.0412
# theta =  3.0580, omega:  0.0685
# theta =  3.0602, omega:  0.0445
# theta =  3.0601, omega:  0.0626
# theta =  3.0607, omega: -0.0013
# theta =  3.0623, omega:  0.0191
# theta =  3.0629, omega:  0.0002
# theta =  3.0637, omega:  0.0003
# theta =  3.0633, omega: -0.0002
# theta =  3.0630, omega:  0.0028
# theta =  3.0601, omega: -0.1703
# theta =  3.0587, omega:  0.0514
# theta =  3.0637, omega:  0.2092
# theta =  3.0646, omega: -0.0333
# theta =  3.0637, omega: -0.0005
# theta =  3.0657, omega:  0.0442
# theta =  3.0640, omega: -0.1635
# theta =  3.0624, omega:  0.0900
# theta =  3.0680, omega:  0.3095
# theta =  3.0693, omega: -0.0731
# theta =  3.0686, omega:  0.0004
# theta =  3.0664, omega: -0.2634
# theta =  3.0645, omega:  0.1123
# theta =  3.0650, omega: -0.1282
# theta =  3.0626, omega: -0.0002
# theta =  3.0635, omega: -0.0003
# theta =  3.0653, omega: -0.0024
# theta =  3.0649, omega:  0.0009
# theta =  3.0618, omega: -0.1358
# theta =  3.0631, omega:  0.0474
# theta =  3.0646, omega:  0.2057
# theta =  3.0657, omega: -0.1728
# theta =  3.0651, omega:  0.1146
# theta =  3.0665, omega: -0.0048
# theta =  3.0646, omega: -0.0857
# theta =  3.0643, omega:  0.0299
# theta =  3.0599, omega: -0.4294
# theta =  3.0534, omega:  0.0447
# theta =  3.0544, omega: -0.0017
# theta =  3.0545, omega:  0.0018
# theta =  3.0544, omega:  0.0021
# theta =  3.0545, omega: -0.0826
# theta =  3.0548, omega:  0.1954
# theta =  3.0619, omega:  0.1690
# theta =  3.0620, omega:  0.0108
# theta =  3.0622, omega:  0.0004
# theta =  3.0635, omega:  0.0860
# theta =  3.0654, omega: -0.0009
# theta =  3.0643, omega: -0.0015
# theta =  3.0631, omega: -0.0010
# theta =  3.0645, omega:  0.0021
# theta =  3.0625, omega: -0.0018
# theta =  3.0625, omega: -0.2063
# theta =  3.0623, omega:  0.0861
# theta =  3.0602, omega:  0.0001
# theta =  3.0616, omega:  0.0003
# theta =  3.0598, omega: -0.2332
# theta =  3.0588, omega:  0.1674
# theta =  3.0589, omega: -0.0772
# theta =  3.0601, omega:  0.1689
# theta =  3.0607, omega: -0.1641
# theta =  3.0596, omega:  0.0554
# theta =  3.0617, omega:  0.0156
# theta =  3.0594, omega: -0.0002
# theta =  3.0595, omega: -0.0021
# theta =  3.0591, omega: -0.0618
# theta =  3.0594, omega: -0.0011
# theta =  3.0597, omega:  0.0204
# theta =  3.0591, omega: -0.0142
# theta =  3.0604, omega:  0.1676
# theta =  3.0616, omega: -0.0015
# theta =  3.0632, omega: -0.0282
# theta =  3.0651, omega:  0.2146
# theta =  3.0653, omega: -0.0984
# theta =  3.0641, omega:  0.0019
# theta =  3.0686, omega:  0.1426
# theta =  3.0704, omega: -0.0023
# theta =  3.0698, omega: -0.0000
# theta =  3.0675, omega: -0.1712
# theta =  3.0667, omega: -0.0009
# theta =  3.0630, omega:  0.0375
# theta =  3.0666, omega:  0.1642
# theta =  3.0665, omega: -0.0486
# theta =  3.0684, omega: -0.0014
# theta =  3.0688, omega: -0.0006
# theta =  3.0680, omega:  0.0024
# theta =  3.0675, omega:  0.0028
# theta =  3.0668, omega:  0.0005
# theta =  3.0644, omega: -0.2261
# theta =  3.0620, omega: -0.0908
# theta =  3.0645, omega:  0.3320
# theta =  3.0685, omega: -0.0307
# theta =  3.0690, omega: -0.0021
# theta =  3.0678, omega: -0.0016
# theta =  3.0662, omega: -0.0811
# theta =  3.0653, omega: -0.0000
# theta =  3.0671, omega:  0.0023
# theta =  3.0645, omega: -0.1220
# theta =  3.0658, omega:  0.1686
# theta =  3.0630, omega: -0.2496
# theta =  3.0611, omega:  0.0285
# theta =  3.0620, omega: -0.0005
# theta =  3.0684, omega:  0.4050
# theta =  3.0724, omega: -0.0066
# theta =  3.0725, omega: -0.0010
# theta =  3.0716, omega: -0.0096
# theta =  3.0715, omega:  0.0004
# theta =  3.0718, omega: -0.0008
# theta =  3.0717, omega:  0.1464
# theta =  3.0751, omega: -0.0674
# theta =  3.0725, omega:  0.0017
# theta =  3.0733, omega:  0.0011
# theta =  3.0733, omega: -0.0087
# theta =  3.0729, omega:  0.1414
# theta =  3.0729, omega: -0.2810
# theta =  3.0704, omega:  0.0160
# theta =  3.0709, omega:  0.0543
# theta =  3.0692, omega: -0.1058
# theta =  3.0683, omega:  0.0005
# theta =  3.0694, omega:  0.0015
# theta =  3.0688, omega: -0.0010
# theta =  3.0676, omega: -0.0007
# theta =  3.0690, omega: -0.0013
# theta =  3.0673, omega: -0.0013
# theta =  3.0690, omega:  0.0391
# theta =  3.0698, omega:  0.0422
# theta =  3.0727, omega:  0.0013
# theta =  3.0717, omega: -0.0734
# theta =  3.0684, omega: -0.0193
# theta =  3.0677, omega: -0.0014
# theta =  3.0694, omega: -0.0018
# theta =  3.0671, omega: -0.0696
# theta =  3.0670, omega:  0.0027
# theta =  3.0684, omega: -0.0104
# theta =  3.0690, omega:  0.2835
# theta =  3.0749, omega:  0.0849
# theta =  3.0769, omega:  0.0007
# theta =  3.0757, omega: -0.1367
# theta =  3.0736, omega:  0.0298
# theta =  3.0766, omega:  0.1829
# theta =  3.0789, omega: -0.0008
# theta =  3.0768, omega: -0.1776
# theta =  3.0759, omega:  0.1524
# theta =  3.0778, omega:  0.0699
# theta =  3.0733, omega: -0.4544
# theta =  3.0687, omega:  0.0213
# theta =  3.0681, omega:  0.0009
# theta =  3.0690, omega: -0.0173
# theta =  3.0618, omega: -0.4491
# theta =  3.0573, omega:  0.0093
# theta =  3.0566, omega:  0.0202
# theta =  3.0580, omega: -0.0004
# theta =  3.0535, omega: -0.1695
# theta =  3.0551, omega:  0.0520
# theta =  3.0555, omega: -0.0007
# theta =  3.0548, omega: -0.0611
# theta =  3.0550, omega:  0.1425
# theta =  3.0586, omega:  0.0565
# theta =  3.0575, omega: -0.0232
# theta =  3.0581, omega: -0.0015
# theta =  3.0576, omega: -0.0000
# theta =  3.0577, omega:  0.0004
# theta =  3.0576, omega: -0.0008
# theta =  3.0567, omega: -0.0004
# theta =  3.0580, omega: -0.0032
# theta =  3.0580, omega: -0.0006
# theta =  3.0616, omega:  0.1745
# theta =  3.0675, omega:  0.4080
# theta =  3.0714, omega: -0.1339
# theta =  3.0699, omega:  0.0003
# theta =  3.0689, omega: -0.0006
# theta =  3.0681, omega: -0.0162
# theta =  3.0674, omega: -0.0955
# theta =  3.0660, omega:  0.0005
# theta =  3.0674, omega:  0.0440
# theta =  3.0688, omega:  0.0170
# theta =  3.0677, omega: -0.0012
# theta =  3.0663, omega: -0.0256
# theta =  3.0681, omega: -0.0005
# theta =  3.0646, omega: -0.0023
# theta =  3.0682, omega:  0.0011
# theta =  3.0667, omega: -0.0910
# theta =  3.0662, omega:  0.0725
# theta =  3.0629, omega: -0.2219
# theta =  3.0603, omega: -0.1709
# theta =  3.0588, omega:  0.0364
# theta =  3.0584, omega: -0.0005
# theta =  3.0589, omega:  0.0003
# theta =  3.0633, omega:  0.2364
# theta =  3.0622, omega: -0.0744
# theta =  3.0631, omega:  0.0001
# theta =  3.0630, omega:  0.2002
# theta =  3.0663, omega: -0.0408
# theta =  3.0668, omega:  0.0850
# theta =  3.0638, omega: -0.2055
# theta =  3.0621, omega: -0.0004
# theta =  3.0631, omega: -0.0395
# theta =  3.0612, omega:  0.0010
# theta =  3.0631, omega:  0.0689
# theta =  3.0636, omega: -0.0013
# theta =  3.0625, omega: -0.0007
# theta =  3.0633, omega: -0.0593
# theta =  3.0648, omega:  0.1482
# theta =  3.0624, omega: -0.2143
# theta =  3.0612, omega:  0.0046
# theta =  3.0599, omega: -0.0002
